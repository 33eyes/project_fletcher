# %%
import csv
from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import re

import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

from IPython.display import Image
import seaborn as sns

import time
# Out:
# C:\Users\Arina\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# pandas display settings

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)
pd.set_option('display.precision', 3)

# %%
# Load the pickled parsed job posts data
df1 = pd.read_pickle('../data_local/job_posts_clean_022618.pkl')
df2 = pd.read_pickle('../data_local/job_posts_clean_022818.pkl')

# %%
print(len(df1))
print(len(df2))
# Out:
# 496
# 128

# %%
# df_all = pd.concat([df1, df2])
df_all = df1.append(df2, ignore_index=True)
print(len(df_all))
# Out:
# 624

# %%
df_all = df_all.drop_duplicates(subset=['company_name', 'job_title'])
df_all = df_all.reset_index(drop=True)
len(df_all)
# Out:
# 428

# %%
df_all.loc[33]
# Out:
# company_descr    Trust is rare in today’s digital advertising l...
# company_name                                         Goodway Group
# date_posted                                             9 days ago
# email_content    Indeed Job Alert data science jobs  Jobs 1-30 ...
# email_date                   Mon, 19 Feb 2018 17:27:47 -0600 (CST)
# email_from                                                  Indeed
# email_subject                            30+ new data science jobs
# job_post_link    https://www.indeed.com/viewjob?jk=d07982277170...
# job_posting      The Director of Data Science & Engineering is ...
# job_title                       Director of Data Science - Virtual
# location                                              New York, NY
# job_role                                     data science director
# job_level                                                   senior
# country                                                        USA
# state                                                           NY
# city                                                      New York
# job_post_date                                           2018-02-17
# Name: 33, dtype: object

# %% [markdown]
# ## Address jargon and specialized language
# (based on insights from TF-IDF and NMF topic modeling during data cleaning)

# %% [markdown]
# ### The equal opportunity clause

# %%
equal_opp_clause_words = "status employment protected gender applicants race color disability religion opportunity sexual age equal orientation qualified veteran sex employer regard identity demonstrated law marital".split(' ')
len(equal_opp_clause_words)
# Out:
# 23

# %%
hr_words = 'job required education master type years salary year location desired minimum include tasks level range highly expert degree bachelor position resume knowledge related duties summary requirements benefits preferred applicants phd present needed need employee employer effectively effective employees'.split()
hr_words
# Out:
# ['job',
#  'required',
#  'education',
#  'master',
#  'type',
#  'years',
#  'salary',
#  'year',
#  'location',
#  'desired',
#  'minimum',
#  'include',
#  'tasks',
#  'level',
#  'range',
#  'highly',
#  'expert',
#  'degree',
#  'bachelor',
#  'position',
#  'resume',
#  'knowledge',
#  'related',
#  'duties',
#  'summary',
#  'requirements',
#  'benefits',
#  'preferred',
#  'applicants',
#  'phd',
#  'present',
#  'needed',
#  'need',
#  'employee',
#  'employer',
#  'effectively',
#  'effective',
#  'employees']

# %%
df_all['equal_opportunity_clause'] = 0
#df_all['hr_words_count'] = 0

for i in range(len(df_all)):
    job_posting = df_all.job_posting[i].lower()
    
    # Equal opp clause
    eqw_count = 0
    for eqw in equal_opp_clause_words:
        if eqw in job_posting:
            eqw_count += 1
            eqw_regex = r"\b" + re.escape(eqw) + r"\b"
            job_posting = re.sub(eqw_regex, r'', job_posting, flags=re.IGNORECASE)
    
    if eqw_count >= 5:
        df_all['equal_opportunity_clause'][i] = 1
        
        
    # Remove generic HR words
    #hrw_count = 0
    for hrw in hr_words:
        if hrw in job_posting:
            hrw_count += 1
            hrw_regex = r"\b" + re.escape(hrw) + r"\b"
            job_posting = re.sub(hrw_regex, r'', job_posting, flags=re.IGNORECASE)
    #df_all['hr_words_count'] = hrw_count
    
    df_all.job_posting[i] = job_posting
# Out:
# C:\Users\Arina\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Arina\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_all.head()
# Out:
#                                        company_descr  \
# 0  At Bluecore we are transforming the way eComme...
# 1
# 2
# 3  About HRG\n\nHRG's TRADING TEAM recruits the t...
# 4
#
#                   company_name date_posted  \
# 0                     Bluecore  7 days ago
# 1                    Loadsmart  7 days ago
# 2                   Foursquare  8 days ago
# 3  The Hagan-Ricci Group, Inc.  9 days ago
# 4                     Oath Inc  8 days ago
#
#                                        email_content  \
# 0  Recommended Jobs for You  Jobs 1 to 23 of 23 r...
# 1  Recommended Jobs for You  Jobs 1 to 23 of 23 r...
# 2  Recommended Jobs for You  Jobs 1 to 23 of 23 r...
# 3  Recommended Jobs for You  Jobs 1 to 23 of 23 r...
# 4  Recommended Jobs for You  Jobs 1 to 23 of 23 r...
#
#                               email_date        email_from  \
# 0  Mon, 19 Feb 2018 13:12:58 -0600 (CST)  Indeed Job Alert
# 1  Mon, 19 Feb 2018 13:12:58 -0600 (CST)  Indeed Job Alert
# 2  Mon, 19 Feb 2018 13:12:58 -0600 (CST)  Indeed Job Alert
# 3  Mon, 19 Feb 2018 13:12:58 -0600 (CST)  Indeed Job Alert
# 4  Mon, 19 Feb 2018 13:12:58 -0600 (CST)  Indeed Job Alert
#
#                                        email_subject  \
# 0  You have new recommended jobs: Senior Data Sci...
# 1  You have new recommended jobs: Senior Data Sci...
# 2  You have new recommended jobs: Senior Data Sci...
# 3  You have new recommended jobs: Senior Data Sci...
# 4  You have new recommended jobs: Senior Data Sci...
#
#                                        job_post_link  \
# 0  https://www.indeed.com/viewjob?jk=6c7ebde0dbd8...
# 1  https://www.indeed.com/viewjob?jk=59a797491eb2...
# 2  https://www.indeed.com/viewjob?jk=7490c513ac10...
# 3  https://www.indeed.com/viewjob?jk=4eceac18fce0...
# 4  https://www.indeed.com/viewjob?jk=6b82f29c6741...
#
#                                          job_posting  \
# 0  we are looking for senior data scientists with...
# 1  who we are:\nat loadsmart, we won't settle for...
# 2  about foursquare:\nsince our inception in 2009...
# 3  a small and very successful quantitative fund ...
# 4  oath, a subsidiary of verizon, is a values-led...
#
#                             job_title            location        job_role  \
# 0               Senior Data Scientist  New York, NY 10002  data scientist
# 1                      Data Scientist        New York, NY  data scientist
# 2                      Data Scientist        New York, NY  data scientist
# 3  Data Scientist / Signal Researcher        New York, NY  data scientist
# 4               Data Scientist Intern        New York, NY  data scientist
#
#   job_level country state      city job_post_date  equal_opportunity_clause
# 0    senior     USA    NY  New York    2018-02-19                         1
# 1               USA    NY  New York    2018-02-19                         0
# 2               USA    NY  New York    2018-02-18                         1
# 3               USA    NY  New York    2018-02-17                         0
# 4    intern     USA    NY  New York    2018-02-18                         1

# %%
len(df_all[df_all['equal_opportunity_clause'] == 1])
# Out:
# 147

# %%
#len(df_all[df_all['hr_words_count'] >= 12])

# %%
print(df_all.job_posting[0])
# Out:
# we are looking for senior data scientists with strong mathematical backgrounds to work alongside our engineering teams to build the next generation of retail and commerce models that delight and empower marketers. the ideal candidate is one that has several  of experience researching, building, serving, and maintaining data science models at scale. they have first-hand experience with what works and what doesn’t, and are eager to share this experience with more junior members and guide them through that process. they are also able to and excited to help architect and build out the data science architecture  to accelerate innovation on models and facilitate serving and maintaining them. finally, they should be curious and eager to identify and explore the myriad of other products that can be built on our data asset. our culture emphasizes making good tradeoffs, working as a team, and leaving your ego at the door.
#
# first-party data is at the core of everything we build and the data science team at bluecore is at the forefront of exploring innovative and exciting ways to activate that data asset. we’re a dedicated team of data scientists and engineers working together to build powerful models that empower marketers to make the right decisions and engage their customers with personalized content. our approach to building models is an academic one, starting with a literature search, a baseline, and an iterative process of training and validation to identify the most suitable model that is as simple as possible and as powerful as necessary. we employ a wide variety of models, such as bayesian models for predicting customer lifetime value, and matrix factorization to identify a customer’s product affinity. our models operate at scale and crunch through millions of data points to make decisions that have been shown to double revenue and triple reach, and are designed in a flexible manner to generalize across our set of 300+ diverse customers who span industries from apparel to automotive. to explore, build, deploy and maintain models we leverage many tools such as bigquery, spark, cloud sql, keras, tensorflow, airflow, google app engine and google compute engine. finally, we’re a team that values applied research and constantly exploring the frontier of what’s possible; diving into topics such as topic modeling, restricted boltzmann machines, recurrent neural networks, convolutional neural networks for image feature extraction, and most recently an extensive dive into differential privacy.
#
# responsibilities
# identify new opportunities to leverage our data asset
# propose and drive technical initiatives
# propose infrastructure to accelerate the pace of model exploration and improve model serving and maintenance
# meet with customers to discuss our models and our roadmap
# identifying appropriate models/algorithms to solve product
# meticulous experimentation to evaluate and compare models
# writing internal and external facing documentation describing models and approaches
# deploying models to production and maintaining them
#
#  or ms in computer science, electrical engineering, applied math, statistics or other relevant quantitative disciplines, or equivalent industry experience
# relevant coursework and experience in the fields of machine learning, statistics, optimization
# deep understanding of statistical/probabilistic analysis and linear algebra
# 3+  of relevant industry experience, including internships
# ability to write production-ready code
# experience with natural language processing, deep learning, reinforcement learning, and/or optimization
# experience with ml at scale
# experience with scale computing: hadoop/scala/spark/cassandra
# experience with sql
#
#  competitive compensation package including  and equity as well as the  to work for one of the fastest growing marketing technology start-ups
# comprehensive medical, dental, and vision insurance
# 401(k) plan
# monthly fitness stipend for a gym membership or fitness classes
# monthly nyc metro card
# generous parental leave & flexible vacation policy
# at bluecore we believe in fostering an inclusive environment in which  feel encouraged to share their unique perspectives, leverage their strengths, and act authentically. we know that diverse teams are strong teams, and welcome those from all backgrounds and varying experiences.
#
# bluecore is a proud   . we are committed to fair hiring practices and to creating a welcoming environment for all team members. all   will receive consideration for  without  to , , , ,   or expression,  , national origin, , , familial  or  .

# %%
from textblob import TextBlob

# %%
jobpost_blob = TextBlob(df_all.job_posting[0])

# %%
jobpost_blob.sentiment
# Out:
# Sentiment(polarity=0.22148574695744508, subjectivity=0.5689761496365269)

# %%
for i in range(len(df_all)):
    print(i)
    print(TextBlob(df_all.job_posting[i]).sentiment)
# Out:
# 0
# Sentiment(polarity=0.22148574695744508, subjectivity=0.5689761496365269)
# 1
# Sentiment(polarity=0.2888095238095238, subjectivity=0.5622619047619047)
# 2
# Sentiment(polarity=0.2820632515632516, subjectivity=0.528485088985089)
# 3
# Sentiment(polarity=0.1291156462585034, subjectivity=0.46977891156462587)
# 4
# Sentiment(polarity=0.1254573799216656, subjectivity=0.4252396413110698)
# 5
# Sentiment(polarity=0.10781750906750909, subjectivity=0.5378483678483678)
# 6
# Sentiment(polarity=0.20629657228017886, subjectivity=0.4956603505783833)
# 7
# Sentiment(polarity=0.01428571428571429, subjectivity=0.3)
# 8
# Sentiment(polarity=0.2072420634920635, subjectivity=0.4114417989417989)
# 9
# Sentiment(polarity=0.2764136904761904, subjectivity=0.4731026785714285)
# 10
# Sentiment(polarity=0.2476590909090909, subjectivity=0.6360025252525252)
# 11
# Sentiment(polarity=0.07974386724386726, subjectivity=0.3918975468975469)
# 12
# Sentiment(polarity=0.11218181818181816, subjectivity=0.5066060606060606)
# 13
# Sentiment(polarity=0.19886243386243388, subjectivity=0.487053317053317)
# 14
# Sentiment(polarity=0.13971262368583795, subjectivity=0.3600348510616368)
# 15
# Sentiment(polarity=0.13893250688705236, subjectivity=0.39495179063360875)
# 16
# Sentiment(polarity=0.09465746753246754, subjectivity=0.38438203463203463)
# 17
# Sentiment(polarity=0.19289813721631907, subjectivity=0.4118129345402073)
# 18
# Sentiment(polarity=0.13530701754385965, subjectivity=0.3385442773600668)
# 19
# Sentiment(polarity=0.13702458256029684, subjectivity=0.4108727581941868)
# 20
# Sentiment(polarity=0.1705357142857143, subjectivity=0.3400510204081632)
# 21
# Sentiment(polarity=0.08883183337130707, subjectivity=0.4858453899901268)
# 22
# Sentiment(polarity=0.2553451178451178, subjectivity=0.4643458393458395)
# 23
# Sentiment(polarity=0.07681337181337178, subjectivity=0.3658152958152957)
# 24
# Sentiment(polarity=0.09999999999999999, subjectivity=0.4897259791490561)
# 25
# Sentiment(polarity=0.10549100022784232, subjectivity=0.4686375028480291)
# 26
# Sentiment(polarity=0.1903138528138528, subjectivity=0.4639610389610391)
# 27
# Sentiment(polarity=0.3170531849103278, subjectivity=0.5766001855287569)
# 28
# Sentiment(polarity=0.06334336395312005, subjectivity=0.32331063245697383)
# 29
# Sentiment(polarity=0.19056122448979593, subjectivity=0.4170918367346938)
# 30
# Sentiment(polarity=0.05349412492269635, subjectivity=0.3283704390847248)
# 31
# Sentiment(polarity=0.1179949874686717, subjectivity=0.4810025062656642)
# 32
# Sentiment(polarity=0.06153846153846154, subjectivity=0.35769230769230764)
# 33
# Sentiment(polarity=0.2888095238095238, subjectivity=0.5622619047619047)
# 34
# Sentiment(polarity=0.2380494505494505, subjectivity=0.4735347985347985)
# 35
# Sentiment(polarity=0.21181216931216934, subjectivity=0.5083928571428571)
# 36
# Sentiment(polarity=0.15919312169312172, subjectivity=0.45026455026455026)
# 37
# Sentiment(polarity=0.26666666666666666, subjectivity=0.5166666666666666)
# 38
# Sentiment(polarity=0.18139952153110048, subjectivity=0.5006237183868762)
# 39
# Sentiment(polarity=0.1125, subjectivity=0.315625)
# 40
# Sentiment(polarity=0.22060822510822517, subjectivity=0.5179361471861471)
# 41
# Sentiment(polarity=0.2820632515632516, subjectivity=0.528485088985089)
# 42
# Sentiment(polarity=0.1348458763458764, subjectivity=0.38160550560550577)
# 43
# Sentiment(polarity=0.28584415584415584, subjectivity=0.5317672258297258)
# 44
# Sentiment(polarity=0.06153846153846154, subjectivity=0.35769230769230764)
# 45
# Sentiment(polarity=0.15202169625246548, subjectivity=0.5351507466892083)
# 46
# Sentiment(polarity=0.27171183888575196, subjectivity=0.4722157914549219)
# 47
# Sentiment(polarity=0.16744934143870316, subjectivity=0.4089817629179331)
# 48
# Sentiment(polarity=0.04648268398268398, subjectivity=0.3301406926406927)
# 49
# Sentiment(polarity=0.18883333333333333, subjectivity=0.4724333333333335)
# 50
# Sentiment(polarity=0.2486000558581204, subjectivity=0.5576351068286552)
# 51
# Sentiment(polarity=0.20708333333333337, subjectivity=0.4224999999999999)
# 52
# Sentiment(polarity=0.22399891774891775, subjectivity=0.5019209956709957)
# 53
# Sentiment(polarity=0.2888095238095238, subjectivity=0.5622619047619047)
# 54
# Sentiment(polarity=0.05696969696969696, subjectivity=0.3787878787878788)
# 55
# Sentiment(polarity=0.1291156462585034, subjectivity=0.46977891156462587)
# 56
# Sentiment(polarity=0.15227272727272725, subjectivity=0.5659090909090909)
# 57
# Sentiment(polarity=0.26176767676767676, subjectivity=0.5278030303030302)
# 58
# Sentiment(polarity=0.2549654710368997, subjectivity=0.4495433138290281)
# 59
# Sentiment(polarity=0.16459156785243736, subjectivity=0.4541501976284586)
# 60
# Sentiment(polarity=0.17978219696969697, subjectivity=0.4670691287878788)
# 61
# Sentiment(polarity=0.17777777777777778, subjectivity=0.41111111111111115)
# 62
# Sentiment(polarity=0.21080125231910948, subjectivity=0.4999710111317253)
# 63
# Sentiment(polarity=0.28230476190476184, subjectivity=0.536647619047619)
# 64
# Sentiment(polarity=0.12413690476190477, subjectivity=0.3322406462585033)
# 65
# Sentiment(polarity=0.21491228070175442, subjectivity=0.5741228070175438)
# 66
# Sentiment(polarity=0.22905303030303034, subjectivity=0.39644412878787877)
# 67
# Sentiment(polarity=0.16596908526256357, subjectivity=0.5503317334839074)
# 68
# Sentiment(polarity=0.11818181818181817, subjectivity=0.4041958041958042)
# 69
# Sentiment(polarity=0.09797121797121798, subjectivity=0.411006591006591)
# 70
# Sentiment(polarity=0.05696969696969696, subjectivity=0.3787878787878788)
# 71
# Sentiment(polarity=0.2171607378129117, subjectivity=0.5346179183135703)
# 72
# Sentiment(polarity=0.31166666666666665, subjectivity=0.6524358974358974)
# 73
# Sentiment(polarity=0.07569812409812415, subjectivity=0.4082333888333887)
# 74
# Sentiment(polarity=0.07532467532467532, subjectivity=0.43246753246753245)
# 75
# Sentiment(polarity=0.06981179389715975, subjectivity=0.2444316861999789)
# 76
# Sentiment(polarity=0.19023125996810208, subjectivity=0.5308919151024414)
# 77
# Sentiment(polarity=0.155543794105438, subjectivity=0.4598567870485678)
# 78
# Sentiment(polarity=0.18425925925925923, subjectivity=0.41574074074074074)
# 79
# Sentiment(polarity=0.03958333333333334, subjectivity=0.5177083333333333)
# 80
# Sentiment(polarity=0.16225490196078435, subjectivity=0.49929971988795513)
# 81
# Sentiment(polarity=0.1430747322852586, subjectivity=0.33268853953064476)
# 82
# Sentiment(polarity=0.0747222222222222, subjectivity=0.4066666666666667)
# 83
# Sentiment(polarity=0.1062905844155844, subjectivity=0.3223823051948052)
# 84
# Sentiment(polarity=-0.007738095238095238, subjectivity=0.2208333333333333)
# 85
# Sentiment(polarity=0.1493693982074264, subjectivity=0.4051813913785747)
# 86
# Sentiment(polarity=0.15123376623376625, subjectivity=0.4688195138195138)
# 87
# Sentiment(polarity=0.11835694608421883, subjectivity=0.2780007870916962)
# 88
# Sentiment(polarity=0.035400299289188183, subjectivity=0.4692012719790498)
# 89
# Sentiment(polarity=0.14691263282172373, subjectivity=0.4307802046438409)
# 90
# Sentiment(polarity=0.10666508288459506, subjectivity=0.36146394256150344)
# 91
# Sentiment(polarity=0.23490034271284277, subjectivity=0.5439694564694565)
# 92
# Sentiment(polarity=0.09999999999999999, subjectivity=0.4897259791490561)
# 93
# Sentiment(polarity=0.21098484848484853, subjectivity=0.4984848484848486)
# 94
# Sentiment(polarity=0.2234408676429953, subjectivity=0.48672538454453346)
# 95
# Sentiment(polarity=0.10549100022784232, subjectivity=0.4686375028480291)
# 96
# Sentiment(polarity=0.15305555555555556, subjectivity=0.4724263038548753)
# 97
# Sentiment(polarity=0.3177489177489177, subjectivity=0.4961038961038961)
# 98
# Sentiment(polarity=0.10832491582491582, subjectivity=0.4453577441077441)
# 99
# Sentiment(polarity=0.1467261904761905, subjectivity=0.351062925170068)
# 100
# Sentiment(polarity=0.265, subjectivity=0.71)
# 101
# Sentiment(polarity=0.08106060606060607, subjectivity=0.4193722943722944)
# 102
# Sentiment(polarity=0.1785545183982684, subjectivity=0.3783786525974026)
# 103
# Sentiment(polarity=0.146900826446281, subjectivity=0.48534041715859905)
# 104
# Sentiment(polarity=0.05294117647058824, subjectivity=0.42903469079939666)
# 105
# Sentiment(polarity=0.22749242424242425, subjectivity=0.4591969696969697)
# 106
# Sentiment(polarity=0.15977342549923193, subjectivity=0.5497548150773957)
# 107
# Sentiment(polarity=0.23967416512059367, subjectivity=0.4541859925788497)
# 108
# Sentiment(polarity=0.20119047619047625, subjectivity=0.3829931972789116)
# 109
# Sentiment(polarity=0.15897655803316188, subjectivity=0.517238421955403)
# 110
# Sentiment(polarity=0.13095959595959597, subjectivity=0.3810576351752823)
# 111
# Sentiment(polarity=0.1802475979305248, subjectivity=0.5013673318551368)
# 112
# Sentiment(polarity=0.12917888563049856, subjectivity=0.4685728250244379)
# 113
# Sentiment(polarity=0.3194444444444444, subjectivity=0.522718253968254)
# 114
# Sentiment(polarity=0.19551714051714053, subjectivity=0.49636597636597635)
# 115
# Sentiment(polarity=0.26176767676767676, subjectivity=0.5278030303030302)
# 116
# Sentiment(polarity=0.17978219696969697, subjectivity=0.4670691287878788)
# 117
# Sentiment(polarity=0.13852080123266564, subjectivity=0.4117360041088855)
# 118
# Sentiment(polarity=0.23126641118444394, subjectivity=0.47653821588247824)
# 119
# Sentiment(polarity=0.2228977272727273, subjectivity=0.4280387205387205)
# 120
# Sentiment(polarity=0.23523113790970934, subjectivity=0.38301252319109463)
# 121
# Sentiment(polarity=0.11486013986013982, subjectivity=0.36459790209790205)
# 122
# Sentiment(polarity=0.15123376623376625, subjectivity=0.4688195138195138)
# 123
# Sentiment(polarity=0.10333021776203594, subjectivity=0.3742671848353667)
# 124
# Sentiment(polarity=0.2150536963036963, subjectivity=0.5028575591075591)
# 125
# Sentiment(polarity=0.0, subjectivity=0.0)
# 126
# Sentiment(polarity=0.1528872335394075, subjectivity=0.42145653863045157)
# 127
# Sentiment(polarity=0.0927847152847153, subjectivity=0.38828650516150515)
# 128
# Sentiment(polarity=0.14390074211502782, subjectivity=0.46244975262832405)
# 129
# Sentiment(polarity=0.15381652661064424, subjectivity=0.4189425770308123)
# 130
# Sentiment(polarity=0.19023125996810208, subjectivity=0.5308919151024414)
# 131
# Sentiment(polarity=0.14718599033816424, subjectivity=0.3919616977225674)
# 132
# Sentiment(polarity=0.155543794105438, subjectivity=0.4598567870485678)
# 133
# Sentiment(polarity=0.08512396694214878, subjectivity=0.518595041322314)
# 134
# Sentiment(polarity=0.11667189952904237, subjectivity=0.47893511250654114)
# 135
# Sentiment(polarity=0.13613636363636364, subjectivity=0.4067045454545455)
# 136
# Sentiment(polarity=0.29433497536945824, subjectivity=0.47331691297208534)
# 137
# Sentiment(polarity=0.2185714285714285, subjectivity=0.4748809523809524)
# 138
# Sentiment(polarity=0.16770202020202019, subjectivity=0.4931204906204906)
# 139
# Sentiment(polarity=-0.007738095238095238, subjectivity=0.2208333333333333)
# 140
# Sentiment(polarity=0.14300620762884916, subjectivity=0.3671373437882872)
# 141
# Sentiment(polarity=0.02148760330578512, subjectivity=0.44889807162534423)
# 142
# Sentiment(polarity=0.16225490196078435, subjectivity=0.49929971988795513)
# 143
# Sentiment(polarity=0.23322259136212628, subjectivity=0.5888704318936879)
# 144
# Sentiment(polarity=0.14691263282172373, subjectivity=0.4307802046438409)
# 145
# Sentiment(polarity=0.18826979472140762, subjectivity=0.48279569892473134)
# 146
# Sentiment(polarity=0.10810220852593735, subjectivity=0.34301489470980984)
# 147
# Sentiment(polarity=0.18425925925925923, subjectivity=0.41574074074074074)
# 148
# Sentiment(polarity=0.03958333333333334, subjectivity=0.5177083333333333)
# 149
# Sentiment(polarity=0.2263544536271809, subjectivity=0.45417814508723603)
# 150
# Sentiment(polarity=0.24298245614035086, subjectivity=0.5460526315789473)
# 151
# Sentiment(polarity=0.06452978056426333, subjectivity=0.3527517884414435)
# 152
# Sentiment(polarity=0.15123376623376625, subjectivity=0.4688195138195138)
# 153
# Sentiment(polarity=0.13403679653679654, subjectivity=0.4896841720371132)
# 154
# Sentiment(polarity=0.0773452380952381, subjectivity=0.4111071428571428)
# 155
# Sentiment(polarity=0.035400299289188183, subjectivity=0.4692012719790498)
# 156
# Sentiment(polarity=0.17977736549165124, subjectivity=0.4701762523191093)
# 157
# Sentiment(polarity=0.23126641118444394, subjectivity=0.47653821588247824)
# 158
# Sentiment(polarity=0.1430747322852586, subjectivity=0.33268853953064476)
# 159
# Sentiment(polarity=0.13852080123266564, subjectivity=0.4117360041088855)
# 160
# Sentiment(polarity=0.23126641118444394, subjectivity=0.47653821588247824)
# 161
# Sentiment(polarity=0.11818181818181817, subjectivity=0.4041958041958042)
# 162
# Sentiment(polarity=0.12558136308136308, subjectivity=0.5514173860327707)
# 163
# Sentiment(polarity=0.3194444444444444, subjectivity=0.522718253968254)
# 164
# Sentiment(polarity=0.18323002754820938, subjectivity=0.5125344352617079)
# 165
# Sentiment(polarity=0.18502714216999935, subjectivity=0.3935271078128221)
# 166
# Sentiment(polarity=0.2514590347923682, subjectivity=0.5065807649140983)
# 167
# Sentiment(polarity=0.21951581027667985, subjectivity=0.5520092226613966)
# 168
# Sentiment(polarity=0.3128362708719851, subjectivity=0.5342841682127397)
# 169
# Sentiment(polarity=0.1695687029020362, subjectivity=0.39702648174870386)
# 170
# Sentiment(polarity=0.21491228070175442, subjectivity=0.5741228070175438)
# 171
# Sentiment(polarity=0.2001488095238095, subjectivity=0.36815476190476193)
# 172
# Sentiment(polarity=0.31338888888888883, subjectivity=0.5649444444444445)
# 173
# Sentiment(polarity=0.1560997910135841, subjectivity=0.36482497387669804)
# 174
# Sentiment(polarity=0.11444281524926685, subjectivity=0.3959921798631476)
# 175
# Sentiment(polarity=0.2918319559228651, subjectivity=0.5274845861209498)
# 176
# Sentiment(polarity=0.26345035173160175, subjectivity=0.5387581168831168)
# 177
# Sentiment(polarity=0.17925, subjectivity=0.387530303030303)
# 178
# Sentiment(polarity=0.18338301043219077, subjectivity=0.4781544957774468)
# 179
# Sentiment(polarity=0.1900570641479732, subjectivity=0.4306926406926406)
# 180
# Sentiment(polarity=0.16118247694334653, subjectivity=0.43146056841709013)
# 181
# Sentiment(polarity=0.21756447453255967, subjectivity=0.42156834300451335)
# 182
# Sentiment(polarity=0.19432900432900435, subjectivity=0.5046277056277055)
# 183
# Sentiment(polarity=0.1294602272727273, subjectivity=0.3921243686868688)
# 184
# Sentiment(polarity=0.2425710227272727, subjectivity=0.6188162878787877)
# 185
# Sentiment(polarity=0.15568422318422315, subjectivity=0.4915620490620491)
# 186
# Sentiment(polarity=0.11054817275747507, subjectivity=0.41024363233665545)
# 187
# Sentiment(polarity=0.11607744107744106, subjectivity=0.42365319865319867)
# 188
# Sentiment(polarity=0.155543794105438, subjectivity=0.4598567870485678)
# 189
# Sentiment(polarity=0.16770202020202019, subjectivity=0.4931204906204906)
# 190
# Sentiment(polarity=0.18625283446712018, subjectivity=0.6139455782312925)
# 191
# Sentiment(polarity=0.17747959183673473, subjectivity=0.4389863945578231)
# 192
# Sentiment(polarity=0.2688775510204081, subjectivity=0.5663265306122449)
# 193
# Sentiment(polarity=0.15381652661064424, subjectivity=0.4189425770308123)
# 194
# Sentiment(polarity=0.006249999999999992, subjectivity=0.53125)
# 195
# Sentiment(polarity=0.12291756854256854, subjectivity=0.4654279401154402)
# 196
# Sentiment(polarity=0.14691263282172373, subjectivity=0.4307802046438409)
# 197
# Sentiment(polarity=0.14718599033816424, subjectivity=0.3919616977225674)
# 198
# Sentiment(polarity=0.1387378246753247, subjectivity=0.4830898268398269)
# 199
# Sentiment(polarity=0.18713730713730714, subjectivity=0.44793428793428797)
# 200
# Sentiment(polarity=0.22134796238244517, subjectivity=0.5061598746081505)
# 201
# Sentiment(polarity=0.1901587301587302, subjectivity=0.5495238095238095)
# 202
# Sentiment(polarity=0.29555785123966943, subjectivity=0.44411157024793385)
# 203
# Sentiment(polarity=0.08181818181818182, subjectivity=0.27259499759499756)
# 204
# Sentiment(polarity=0.1109719645433931, subjectivity=0.5083797155225728)
# 205
# Sentiment(polarity=0.1005357142857143, subjectivity=0.500171130952381)
# 206
# Sentiment(polarity=0.04656868429189858, subjectivity=0.43902288188002475)
# 207
# Sentiment(polarity=0.2185714285714285, subjectivity=0.4748809523809524)
# 208
# Sentiment(polarity=0.13613636363636364, subjectivity=0.4067045454545455)
# 209
# Sentiment(polarity=-0.007738095238095238, subjectivity=0.2208333333333333)
# 210
# Sentiment(polarity=0.17309736015618368, subjectivity=0.49178889737713277)
# 211
# Sentiment(polarity=0.16013347763347766, subjectivity=0.49335497835497844)
# 212
# Sentiment(polarity=0.16225490196078435, subjectivity=0.49929971988795513)
# 213
# Sentiment(polarity=0.22060822510822517, subjectivity=0.5179361471861471)
# 214
# Sentiment(polarity=0.21729166666666666, subjectivity=0.3983333333333333)
# 215
# Sentiment(polarity=0.16594887955182072, subjectivity=0.4184407096171803)
# 216
# Sentiment(polarity=0.1294602272727273, subjectivity=0.3921243686868688)
# 217
# Sentiment(polarity=0.2425710227272727, subjectivity=0.6188162878787877)
# 218
# Sentiment(polarity=0.15568422318422315, subjectivity=0.4915620490620491)
# 219
# Sentiment(polarity=0.11054817275747507, subjectivity=0.41024363233665545)
# 220
# Sentiment(polarity=0.11607744107744106, subjectivity=0.42365319865319867)
# 221
# Sentiment(polarity=0.155543794105438, subjectivity=0.4598567870485678)
# 222
# Sentiment(polarity=0.16770202020202019, subjectivity=0.4931204906204906)
# 223
# Sentiment(polarity=0.18625283446712018, subjectivity=0.6139455782312925)
# 224
# Sentiment(polarity=0.17747959183673473, subjectivity=0.4389863945578231)
# 225
# Sentiment(polarity=0.2688775510204081, subjectivity=0.5663265306122449)
# 226
# Sentiment(polarity=0.15381652661064424, subjectivity=0.4189425770308123)
# 227
# Sentiment(polarity=0.12291756854256854, subjectivity=0.4654279401154402)
# 228
# Sentiment(polarity=0.006249999999999992, subjectivity=0.53125)
# 229
# Sentiment(polarity=0.14691263282172373, subjectivity=0.4307802046438409)
# 230
# Sentiment(polarity=0.14718599033816424, subjectivity=0.3919616977225674)
# 231
# Sentiment(polarity=0.1387378246753247, subjectivity=0.4830898268398269)
# 232
# Sentiment(polarity=0.18713730713730714, subjectivity=0.44793428793428797)
# 233
# Sentiment(polarity=0.22134796238244517, subjectivity=0.5061598746081505)
# 234
# Sentiment(polarity=0.1901587301587302, subjectivity=0.5495238095238095)
# 235
# Sentiment(polarity=0.08181818181818182, subjectivity=0.27259499759499756)
# 236
# Sentiment(polarity=0.1109719645433931, subjectivity=0.5083797155225728)
# 237
# Sentiment(polarity=0.29555785123966943, subjectivity=0.44411157024793385)
# 238
# Sentiment(polarity=0.2185714285714285, subjectivity=0.4748809523809524)
# 239
# Sentiment(polarity=0.1005357142857143, subjectivity=0.500171130952381)
# 240
# Sentiment(polarity=0.17309736015618368, subjectivity=0.49178889737713277)
# 241
# Sentiment(polarity=0.04656868429189858, subjectivity=0.43902288188002475)
# 242
# Sentiment(polarity=-0.007738095238095238, subjectivity=0.2208333333333333)
# 243
# Sentiment(polarity=0.13613636363636364, subjectivity=0.4067045454545455)
# 244
# Sentiment(polarity=0.16013347763347766, subjectivity=0.49335497835497844)
# 245
# Sentiment(polarity=0.08512396694214878, subjectivity=0.518595041322314)
# 246
# Sentiment(polarity=0.18713730713730714, subjectivity=0.44793428793428797)
# 247
# Sentiment(polarity=0.2502998737373738, subjectivity=0.5182449494949495)
# 248
# Sentiment(polarity=0.2688775510204081, subjectivity=0.5663265306122449)
# 249
# Sentiment(polarity=0.12529761904761905, subjectivity=0.5539666473877)
# 250
# Sentiment(polarity=0.20119047619047625, subjectivity=0.3829931972789116)
# 251
# Sentiment(polarity=0.23967416512059367, subjectivity=0.4541859925788497)
# 252
# Sentiment(polarity=0.08512396694214878, subjectivity=0.518595041322314)
# 253
# Sentiment(polarity=0.1201697530864198, subjectivity=0.49896604938271605)
# 254
# Sentiment(polarity=0.3194444444444444, subjectivity=0.522718253968254)
# 255
# Sentiment(polarity=0.18323002754820938, subjectivity=0.5125344352617079)
# 256
# Sentiment(polarity=0.12302188552188555, subjectivity=0.520412457912458)
# 257
# Sentiment(polarity=0.09737191502655426, subjectivity=0.3750841083315308)
# 258
# Sentiment(polarity=0.18502714216999935, subjectivity=0.3935271078128221)
# 259
# Sentiment(polarity=0.21361013986013988, subjectivity=0.48780303030303024)
# 260
# Sentiment(polarity=0.39189342403628113, subjectivity=0.4942176870748301)
# 261
# Sentiment(polarity=0.1514005940867643, subjectivity=0.4748940775536519)
# 262
# Sentiment(polarity=0.14700460829493087, subjectivity=0.437826420890937)
# 263
# Sentiment(polarity=0.276933621933622, subjectivity=0.4819480519480519)
# 264
# Sentiment(polarity=0.22626511419614873, subjectivity=0.5423386000972208)
# 265
# Sentiment(polarity=0.15302614052614052, subjectivity=0.41829836829836825)
# 266
# Sentiment(polarity=0.13078651421042722, subjectivity=0.44446993224167136)
# 267
# Sentiment(polarity=0.2688775510204081, subjectivity=0.5663265306122449)
# 268
# Sentiment(polarity=0.2900493025493026, subjectivity=0.493903318903319)
# 269
# Sentiment(polarity=0.22060822510822517, subjectivity=0.5179361471861471)
# 270
# Sentiment(polarity=0.18412532822368888, subjectivity=0.37610212192179415)
# 271
# Sentiment(polarity=0.16594887955182072, subjectivity=0.4184407096171803)
# 272
# Sentiment(polarity=0.19604703206398127, subjectivity=0.3785072272360407)
# 273
# Sentiment(polarity=0.07966269841269841, subjectivity=0.376686507936508)
# 274
# Sentiment(polarity=0.16730379188712524, subjectivity=0.36418724793724805)
# 275
# Sentiment(polarity=0.08143826659451663, subjectivity=0.34758522727272734)
# 276
# Sentiment(polarity=0.20262662869045844, subjectivity=0.4906664257728087)
# 277
# Sentiment(polarity=0.16581093325279378, subjectivity=0.5019002315513944)
# 278
# Sentiment(polarity=0.1736038961038961, subjectivity=0.4913124375624375)
# 279
# Sentiment(polarity=0.13024193548387095, subjectivity=0.43575268817204293)
# 280
# Sentiment(polarity=0.14523809523809522, subjectivity=0.2261904761904762)
# 281
# Sentiment(polarity=0.22796296296296303, subjectivity=0.4208796296296295)
# 282
# Sentiment(polarity=0.148984593837535, subjectivity=0.4035714285714286)
# 283
# Sentiment(polarity=0.32721693121693124, subjectivity=0.6068571428571429)
# 284
# Sentiment(polarity=0.1294602272727273, subjectivity=0.3921243686868688)
# 285
# Sentiment(polarity=0.29433497536945824, subjectivity=0.47331691297208534)
# 286
# Sentiment(polarity=0.12291756854256854, subjectivity=0.4654279401154402)
# 287
# Sentiment(polarity=0.18488612836438928, subjectivity=0.48734472049689453)
# 288
# Sentiment(polarity=-0.01428571428571429, subjectivity=0.31587301587301586)
# 289
# Sentiment(polarity=0.10352586010480751, subjectivity=0.522582023239918)
# 290
# Sentiment(polarity=0.2068076441102757, subjectivity=0.46264724310776945)
# 291
# Sentiment(polarity=0.2185714285714285, subjectivity=0.4748809523809524)
# 292
# Sentiment(polarity=0.17403392440892437, subjectivity=0.42184498834498824)
# 293
# Sentiment(polarity=-0.031818181818181815, subjectivity=0.35454545454545455)
# 294
# Sentiment(polarity=0.1560606060606061, subjectivity=0.38863636363636367)
# 295
# Sentiment(polarity=0.10486542443064181, subjectivity=0.4616459627329193)
# 296
# Sentiment(polarity=0.08099999999999999, subjectivity=0.391142857142857)
# 297
# Sentiment(polarity=0.11088758860187437, subjectivity=0.41886670472384757)
# 298
# Sentiment(polarity=0.12121321439503265, subjectivity=0.39635423499059863)
# 299
# Sentiment(polarity=0.09358866442199776, subjectivity=0.4757996632996633)
# 300
# Sentiment(polarity=0.16013347763347766, subjectivity=0.49335497835497844)
# 301
# Sentiment(polarity=0.20057053453792584, subjectivity=0.4522986071899115)
# 302
# Sentiment(polarity=0.17032828282828288, subjectivity=0.4234267275933942)
# 303
# Sentiment(polarity=0.11054817275747507, subjectivity=0.41024363233665545)
# 304
# Sentiment(polarity=0.15985729386892175, subjectivity=0.4202884324977348)
# 305
# Sentiment(polarity=0.21848811565792703, subjectivity=0.4999019848076451)
# 306
# Sentiment(polarity=0.14718599033816424, subjectivity=0.3919616977225674)
# 307
# Sentiment(polarity=0.12648857838589983, subjectivity=0.3245888412183055)
# 308
# Sentiment(polarity=0.1908313817330211, subjectivity=0.38092896174863383)
# 309
# Sentiment(polarity=0.1665343915343915, subjectivity=0.36779100529100534)
# 310
# Sentiment(polarity=0.14022038567493114, subjectivity=0.4423110979929162)
# 311
# Sentiment(polarity=0.08808590834452905, subjectivity=0.453259814897746)
# 312
# Sentiment(polarity=0.14691263282172373, subjectivity=0.4307802046438409)
# 313
# Sentiment(polarity=0.13725016118633138, subjectivity=0.42812701482914245)
# 314
# Sentiment(polarity=0.11818181818181817, subjectivity=0.4041958041958042)
# 315
# Sentiment(polarity=0.22060822510822517, subjectivity=0.5179361471861471)
# 316
# Sentiment(polarity=0.2900493025493026, subjectivity=0.493903318903319)
# 317
# Sentiment(polarity=0.12529761904761905, subjectivity=0.5539666473877)
# 318
# Sentiment(polarity=0.20119047619047625, subjectivity=0.3829931972789116)
# 319
# Sentiment(polarity=0.21552631578947368, subjectivity=0.45921052631578957)
# 320
# Sentiment(polarity=0.1325915404040404, subjectivity=0.45696022727272717)
# 321
# Sentiment(polarity=0.3194444444444444, subjectivity=0.522718253968254)
# 322
# Sentiment(polarity=0.16727002164502164, subjectivity=0.43722426124600033)
# 323
# Sentiment(polarity=0.20791500166500165, subjectivity=0.5484414890664889)
# 324
# Sentiment(polarity=0.08153846153846155, subjectivity=0.3876923076923076)
# 325
# Sentiment(polarity=0.11467126623376621, subjectivity=0.41060103091353084)
# 326
# Sentiment(polarity=0.09711418306779136, subjectivity=0.37379544853771635)
# 327
# Sentiment(polarity=0.17978219696969697, subjectivity=0.4670691287878788)
# 328
# Sentiment(polarity=0.16943845161930268, subjectivity=0.47128855187365826)
# 329
# Sentiment(polarity=0.18709790209790206, subjectivity=0.5610314685314685)
# 330
# Sentiment(polarity=0.10486542443064181, subjectivity=0.4616459627329193)
# 331
# Sentiment(polarity=0.20021825396825396, subjectivity=0.49918650793650793)
# 332
# Sentiment(polarity=0.03381060606060606, subjectivity=0.3457932900432901)
# 333
# Sentiment(polarity=0.18713730713730714, subjectivity=0.44793428793428797)
# 334
# Sentiment(polarity=0.0, subjectivity=0.0)
# 335
# Sentiment(polarity=0.23358308358308358, subjectivity=0.4795870795870796)
# 336
# Sentiment(polarity=0.10230654761904762, subjectivity=0.3436755952380952)
# 337
# Sentiment(polarity=0.1493844696969697, subjectivity=0.5533143939393941)
# 338
# Sentiment(polarity=0.1125151515151515, subjectivity=0.40703030303030296)
# 339
# Sentiment(polarity=0.058539637445887444, subjectivity=0.33227059398934394)
# 340
# Sentiment(polarity=0.15159007659007662, subjectivity=0.4084443334443334)
# 341
# Sentiment(polarity=0.11649560117302053, subjectivity=0.273533724340176)
# 342
# Sentiment(polarity=0.07202797202797201, subjectivity=0.46317016317016313)
# 343
# Sentiment(polarity=0.11293073593073592, subjectivity=0.44613419913419927)
# 344
# Sentiment(polarity=0.17196969696969697, subjectivity=0.518073593073593)
# 345
# Sentiment(polarity=0.10617529236932224, subjectivity=0.4023333010273308)
# 346
# Sentiment(polarity=0.2345030663780664, subjectivity=0.4174714472035901)
# 347
# Sentiment(polarity=0.21416666666666662, subjectivity=0.5116649091649091)
# 348
# Sentiment(polarity=0.21358543417366943, subjectivity=0.39628851540616244)
# 349
# Sentiment(polarity=0.16590405284370807, subjectivity=0.47795603821465904)
# 350
# Sentiment(polarity=0.11424415584415583, subjectivity=0.4415567099567099)
# 351
# Sentiment(polarity=0.10907873376623381, subjectivity=0.47499458874458866)
# 352
# Sentiment(polarity=0.3516666666666666, subjectivity=0.5916666666666666)
# 353
# Sentiment(polarity=0.19620379620379622, subjectivity=0.5737012987012986)
# 354
# Sentiment(polarity=0.12811220311220312, subjectivity=0.3945331695331695)
# 355
# Sentiment(polarity=0.16770202020202019, subjectivity=0.4931204906204906)
# 356
# Sentiment(polarity=0.12031579531579532, subjectivity=0.4027722277722277)
# 357
# Sentiment(polarity=0.16959345002823262, subjectivity=0.4498870694522868)
# 358
# Sentiment(polarity=0.16309031877213695, subjectivity=0.436211137347501)
# 359
# Sentiment(polarity=0.15, subjectivity=0.43409090909090914)
# 360
# Sentiment(polarity=0.22898550724637676, subjectivity=0.5719367588932807)
# 361
# Sentiment(polarity=0.2289996036827023, subjectivity=0.4929586610572526)
# 362
# Sentiment(polarity=0.21944444444444444, subjectivity=0.37777777777777777)
# 363
# Sentiment(polarity=0.04239130434782609, subjectivity=0.2587792642140468)
# 364
# Sentiment(polarity=0.0961317722681359, subjectivity=0.37254361799816355)
# 365
# Sentiment(polarity=0.1810035842293907, subjectivity=0.4473688497882047)
# 366
# Sentiment(polarity=0.1726538494185553, subjectivity=0.5065138782785841)
# 367
# Sentiment(polarity=0.17752525252525253, subjectivity=0.5954545454545452)
# 368
# Sentiment(polarity=0.1294602272727273, subjectivity=0.3921243686868688)
# 369
# Sentiment(polarity=0.11840966051492365, subjectivity=0.36451925267714735)
# 370
# Sentiment(polarity=0.29433497536945824, subjectivity=0.47331691297208534)
# 371
# Sentiment(polarity=0.14394606782106784, subjectivity=0.4326085858585859)
# 372
# Sentiment(polarity=0.12291756854256854, subjectivity=0.4654279401154402)
# 373
# Sentiment(polarity=0.2952516233766234, subjectivity=0.4636363636363637)
# 374
# Sentiment(polarity=0.20385480747322854, subjectivity=0.45074618364092045)
# 375
# Sentiment(polarity=0.2185714285714285, subjectivity=0.4748809523809524)
# 376
# Sentiment(polarity=0.15890909090909094, subjectivity=0.34913744588744583)
# 377
# Sentiment(polarity=-0.01428571428571429, subjectivity=0.31587301587301586)
# 378
# Sentiment(polarity=0.18488612836438928, subjectivity=0.48734472049689453)
# 379
# Sentiment(polarity=0.20021825396825396, subjectivity=0.49918650793650793)
# 380
# Sentiment(polarity=0.10352586010480751, subjectivity=0.522582023239918)
# 381
# Sentiment(polarity=0.1715601965601966, subjectivity=0.4277231777231777)
# 382
# Sentiment(polarity=0.2068076441102757, subjectivity=0.46264724310776945)
# 383
# Sentiment(polarity=0.1560606060606061, subjectivity=0.38863636363636367)
# 384
# Sentiment(polarity=-0.031818181818181815, subjectivity=0.35454545454545455)
# 385
# Sentiment(polarity=0.0, subjectivity=0.0)
# 386
# Sentiment(polarity=0.20057053453792584, subjectivity=0.4522986071899115)
# 387
# Sentiment(polarity=0.17403392440892437, subjectivity=0.42184498834498824)
# 388
# Sentiment(polarity=0.14022038567493114, subjectivity=0.4423110979929162)
# 389
# Sentiment(polarity=0.14718599033816424, subjectivity=0.3919616977225674)
# 390
# Sentiment(polarity=0.16013347763347766, subjectivity=0.49335497835497844)
# 391
# Sentiment(polarity=-0.1, subjectivity=0.6)
# 392
# Sentiment(polarity=0.21804653679653682, subjectivity=0.5031858766233769)
# 393
# Sentiment(polarity=0.09358866442199776, subjectivity=0.4757996632996633)
# 394
# Sentiment(polarity=0.11351748645055733, subjectivity=0.39870783197554854)
# 395
# Sentiment(polarity=0.11054817275747507, subjectivity=0.41024363233665545)
# 396
# Sentiment(polarity=0.14880952380952384, subjectivity=0.376734693877551)
# 397
# Sentiment(polarity=0.15452651515151516, subjectivity=0.45376893939393953)
# 398
# Sentiment(polarity=0.20254820936639117, subjectivity=0.4640495867768595)
# 399
# Sentiment(polarity=0.24314574314574317, subjectivity=0.5268879268879268)
# 400
# Sentiment(polarity=0.18709790209790206, subjectivity=0.5610314685314685)
# 401
# Sentiment(polarity=0.16661378394332943, subjectivity=0.49604486422668254)
# 402
# Sentiment(polarity=0.20026014865637506, subjectivity=0.504399656946827)
# 403
# Sentiment(polarity=0.23967416512059367, subjectivity=0.4541859925788497)
# 404
# Sentiment(polarity=0.1201697530864198, subjectivity=0.49896604938271605)
# 405
# Sentiment(polarity=0.1802475979305248, subjectivity=0.5013673318551368)
# 406
# Sentiment(polarity=0.3194444444444444, subjectivity=0.522718253968254)
# 407
# Sentiment(polarity=0.12917888563049856, subjectivity=0.4685728250244379)
# 408
# Sentiment(polarity=0.1426163972082339, subjectivity=0.3627904408516653)
# 409
# Sentiment(polarity=0.21052319527319524, subjectivity=0.528156897156897)
# 410
# Sentiment(polarity=0.17978219696969697, subjectivity=0.4670691287878788)
# 411
# Sentiment(polarity=0.3251683501683502, subjectivity=0.45969696969696955)
# 412
# Sentiment(polarity=0.13446692842041677, subjectivity=0.41395441767534785)
# 413
# Sentiment(polarity=0.0, subjectivity=0.0)
# 414
# Sentiment(polarity=0.025628875628875624, subjectivity=0.36595881595881585)
# 415
# Sentiment(polarity=0.24314574314574317, subjectivity=0.5268879268879268)
# 416
# Sentiment(polarity=0.14583333333333334, subjectivity=0.3902777777777778)
# 417
# Sentiment(polarity=0.11875000000000002, subjectivity=0.3555803571428571)
# 418
# Sentiment(polarity=0.18997455558625773, subjectivity=0.5484148475637837)
# 419
# Sentiment(polarity=0.1058886849584524, subjectivity=0.37972066692996925)
# 420
# Sentiment(polarity=0.12680519480519484, subjectivity=0.45835064935064934)
# 421
# Sentiment(polarity=0.20254820936639117, subjectivity=0.4640495867768595)
# 422
# Sentiment(polarity=0.17611883116883115, subjectivity=0.521588961038961)
# 423
# Sentiment(polarity=0.19824404761904765, subjectivity=0.4904464285714286)
# 424
# Sentiment(polarity=0.16013347763347766, subjectivity=0.49335497835497844)
# 425
# Sentiment(polarity=0.1794045102184637, subjectivity=0.4554716601228228)
# 426
# Sentiment(polarity=0.19358315295815298, subjectivity=0.531679894179894)
# 427
# Sentiment(polarity=0.10936507936507936, subjectivity=0.34805555555555556)
# 428
# Sentiment(polarity=0.2065323565323566, subjectivity=0.49340659340659343)
# 429
# Sentiment(polarity=0.11088758860187437, subjectivity=0.41886670472384757)
# 430
# Sentiment(polarity=0.21563973063973066, subjectivity=0.5512373737373736)
# 431
# Sentiment(polarity=0.32705627705627704, subjectivity=0.42646103896103893)
# 432
# Sentiment(polarity=0.11785714285714285, subjectivity=0.46071428571428574)
# 433
# Sentiment(polarity=0.09272255522255521, subjectivity=0.304491341991342)
# 434
# Sentiment(polarity=0.18672766627312082, subjectivity=0.46528269710087894)
# 435
# Sentiment(polarity=0.18092784992784997, subjectivity=0.49109812409812403)
# 436
# Sentiment(polarity=0.07110564167015782, subjectivity=0.5356811199553134)
# 437
# Sentiment(polarity=0.29124999999999995, subjectivity=0.5808333333333333)
# 438
# Sentiment(polarity=0.11636580086580087, subjectivity=0.4924058441558442)
# 439
# Sentiment(polarity=0.1732125307125307, subjectivity=0.4078480753480754)
# 440
# Sentiment(polarity=0.17685185185185184, subjectivity=0.5412037037037036)
# 441
# Sentiment(polarity=0.20717343553882023, subjectivity=0.5254341812034119)
# 442
# Sentiment(polarity=0.23778381482463115, subjectivity=0.4947831080484143)
# 443
# Sentiment(polarity=0.17698773448773453, subjectivity=0.4247077922077922)
# 444
# Sentiment(polarity=0.0184205500381971, subjectivity=0.3093009931245225)
# 445
# Sentiment(polarity=0.19569597069597072, subjectivity=0.4028846153846154)
# 446
# Sentiment(polarity=0.2021098901098901, subjectivity=0.5171538461538462)
# 447
# Sentiment(polarity=0.21197916666666666, subjectivity=0.6135416666666667)
# 448
# Sentiment(polarity=0.06857413419913422, subjectivity=0.2990530303030303)
# 449
# Sentiment(polarity=0.11136363636363637, subjectivity=0.43939393939393945)
# 450
# Sentiment(polarity=0.14854497354497356, subjectivity=0.4947089947089947)
# 451
# Sentiment(polarity=0.012499999999999983, subjectivity=0.4770833333333334)
# 452
# Sentiment(polarity=0.1294602272727273, subjectivity=0.3921243686868688)
# 453
# Sentiment(polarity=0.11840966051492365, subjectivity=0.36451925267714735)
# 454
# Sentiment(polarity=0.29433497536945824, subjectivity=0.47331691297208534)
# 455
# Sentiment(polarity=0.12291756854256854, subjectivity=0.4654279401154402)
# 456
# Sentiment(polarity=0.0, subjectivity=0.0)
# 457
# Sentiment(polarity=0.14394606782106784, subjectivity=0.4326085858585859)
# 458
# Sentiment(polarity=0.3143356643356643, subjectivity=0.5497086247086247)
# 459
# Sentiment(polarity=0.2185714285714285, subjectivity=0.4748809523809524)
# 460
# Sentiment(polarity=0.1560606060606061, subjectivity=0.38863636363636367)
# 461
# Sentiment(polarity=0.20385480747322854, subjectivity=0.45074618364092045)
# 462
# Sentiment(polarity=0.15890909090909094, subjectivity=0.34913744588744583)
# 463
# Sentiment(polarity=0.20021825396825396, subjectivity=0.49918650793650793)
# 464
# Sentiment(polarity=0.18488612836438928, subjectivity=0.48734472049689453)
# 465
# Sentiment(polarity=-0.01428571428571429, subjectivity=0.31587301587301586)
# 466
# Sentiment(polarity=-0.031818181818181815, subjectivity=0.35454545454545455)
# 467
# Sentiment(polarity=0.10352586010480751, subjectivity=0.522582023239918)
# 468
# Sentiment(polarity=0.2952516233766234, subjectivity=0.4636363636363637)
# 469
# Sentiment(polarity=0.1322860962566845, subjectivity=0.29694104914693153)
# 470
# Sentiment(polarity=0.20057053453792584, subjectivity=0.4522986071899115)
# 471
# Sentiment(polarity=0.16013347763347766, subjectivity=0.49335497835497844)
# 472
# Sentiment(polarity=0.14718599033816424, subjectivity=0.3919616977225674)
# 473
# Sentiment(polarity=0.09358866442199776, subjectivity=0.4757996632996633)
# 474
# Sentiment(polarity=0.2068076441102757, subjectivity=0.46264724310776945)
# 475
# Sentiment(polarity=0.11054817275747507, subjectivity=0.41024363233665545)
# 476
# Sentiment(polarity=0.2528535353535354, subjectivity=0.568181818181818)
# 477
# Sentiment(polarity=0.14022038567493114, subjectivity=0.4423110979929162)
# 478
# Sentiment(polarity=0.1715601965601966, subjectivity=0.4277231777231777)
# 479
# Sentiment(polarity=0.17403392440892437, subjectivity=0.42184498834498824)
# 480
# Sentiment(polarity=0.09954055378583682, subjectivity=0.36684227721963586)
# 481
# Sentiment(polarity=0.14691263282172373, subjectivity=0.4307802046438409)
# 482
# Sentiment(polarity=0.24314574314574317, subjectivity=0.5268879268879268)
# 483
# Sentiment(polarity=0.025628875628875624, subjectivity=0.36595881595881585)
# 484
# Sentiment(polarity=0.13446692842041677, subjectivity=0.41395441767534785)
# 485
# Sentiment(polarity=0.09954055378583682, subjectivity=0.36684227721963586)
# 486
# Sentiment(polarity=0.06833506493506492, subjectivity=0.30628831168831167)
# 487
# Sentiment(polarity=0.17777777777777778, subjectivity=0.41111111111111115)
# 488
# Sentiment(polarity=0.18374053030303028, subjectivity=0.4701420454545454)
# 489
# Sentiment(polarity=0.21491228070175442, subjectivity=0.5741228070175438)
# 490
# Sentiment(polarity=0.2236551050575441, subjectivity=0.4773453172843416)
# 491
# Sentiment(polarity=0.12756433381433382, subjectivity=0.46201830576830566)
# 492
# Sentiment(polarity=0.15371212121212122, subjectivity=0.4323737373737373)
# 493
# Sentiment(polarity=0.0, subjectivity=0.0)
# 494
# Sentiment(polarity=0.16589683901004657, subjectivity=0.5045474965286286)
# 495
# Sentiment(polarity=0.21815711462450596, subjectivity=0.45028820816864296)
# 496
# Sentiment(polarity=0.1322860962566845, subjectivity=0.29694104914693153)
# 497
# Sentiment(polarity=0.18852588383838378, subjectivity=0.5156881313131313)
# 498
# Sentiment(polarity=0.13200371057513915, subjectivity=0.33048855905998764)
# 499
# Sentiment(polarity=0.3224770021645022, subjectivity=0.5182021103896104)
# 500
# Sentiment(polarity=0.2001328217237308, subjectivity=0.5645562770562771)
# 501
# Sentiment(polarity=0.1665343915343915, subjectivity=0.36779100529100534)
# 502
# Sentiment(polarity=0.11742023408690078, subjectivity=0.5285553952220617)
# 503
# Sentiment(polarity=0.20262662869045844, subjectivity=0.4906664257728087)
# 504
# Sentiment(polarity=0.2014367816091954, subjectivity=0.4821839080459769)
# 505
# Sentiment(polarity=0.05, subjectivity=0.4875)
# 506
# Sentiment(polarity=0.08060804119627653, subjectivity=0.3989192398015926)
# 507
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.13333333333333333)
# 508
# Sentiment(polarity=0.08128229297584133, subjectivity=0.45979786342689577)
# 509
# Sentiment(polarity=0.16363636363636364, subjectivity=0.571969696969697)
# 510
# Sentiment(polarity=0.10902380952380956, subjectivity=0.4643095238095238)
# 511
# Sentiment(polarity=0.0, subjectivity=0.0)
# 512
# Sentiment(polarity=0.28062169312169316, subjectivity=0.572663139329806)
# 513
# Sentiment(polarity=0.21637909709338282, subjectivity=0.46896032538889676)
# 514
# Sentiment(polarity=0.19178787878787878, subjectivity=0.5197651515151515)
# 515
# Sentiment(polarity=0.2331146744412051, subjectivity=0.43695335276967934)
# 516
# Sentiment(polarity=0.1344055944055944, subjectivity=0.3927301864801866)
# 517
# Sentiment(polarity=0.090255772005772, subjectivity=0.49761580086580093)
# 518
# Sentiment(polarity=0.15684523809523807, subjectivity=0.4523809523809523)
# 519
# Sentiment(polarity=0.0, subjectivity=0.0)
# 520
# Sentiment(polarity=0.19495238095238096, subjectivity=0.5332857142857143)
# 521
# Sentiment(polarity=0.07671428571428571, subjectivity=0.38114285714285706)
# 522
# Sentiment(polarity=0.09152892561983471, subjectivity=0.31728978092614457)
# 523
# Sentiment(polarity=0.16788131313131313, subjectivity=0.4498914141414141)
# 524
# Sentiment(polarity=0.09051837992515961, subjectivity=0.45320089515004763)
# 525
# Sentiment(polarity=0.20385480747322854, subjectivity=0.45074618364092045)
# 526
# Sentiment(polarity=0.03958333333333333, subjectivity=0.4258333333333334)
# 527
# Sentiment(polarity=0.24477777777777776, subjectivity=0.4824444444444444)
# 528
# Sentiment(polarity=0.2952516233766234, subjectivity=0.4636363636363637)
# 529
# Sentiment(polarity=0.3143356643356643, subjectivity=0.5497086247086247)
# 530
# Sentiment(polarity=0.14691263282172373, subjectivity=0.4307802046438409)
# 531
# Sentiment(polarity=0.2044871794871795, subjectivity=0.5067307692307691)
# 532
# Sentiment(polarity=0.12045454545454544, subjectivity=0.5142602495543671)
# 533
# Sentiment(polarity=0.12502145842663087, subjectivity=0.33885984704950234)
# 534
# Sentiment(polarity=0.24412878787878786, subjectivity=0.43602453102453104)
# 535
# Sentiment(polarity=0.09954055378583682, subjectivity=0.36684227721963586)
# 536
# Sentiment(polarity=0.0760403329065301, subjectivity=0.33815087494664975)
# 537
# Sentiment(polarity=0.1322860962566845, subjectivity=0.29694104914693153)
# 538
# Sentiment(polarity=0.24984583598219962, subjectivity=0.5092477219749948)
# 539
# Sentiment(polarity=0.045, subjectivity=0.19666666666666668)
# 540
# Sentiment(polarity=0.1080128205128205, subjectivity=0.49807692307692303)
# 541
# Sentiment(polarity=0.13469615800865803, subjectivity=0.43564714452214454)
# 542
# Sentiment(polarity=0.28652777777777777, subjectivity=0.6315277777777778)
# 543
# Sentiment(polarity=0.1768759018759019, subjectivity=0.5768217893217893)
# 544
# Sentiment(polarity=0.2298570611778159, subjectivity=0.46239565465980553)
# 545
# Sentiment(polarity=0.1356821563852814, subjectivity=0.3735465922965924)
# 546
# Sentiment(polarity=0.20254820936639117, subjectivity=0.4640495867768595)
# 547
# Sentiment(polarity=0.13200371057513915, subjectivity=0.33048855905998764)
# 548
# Sentiment(polarity=0.24314574314574317, subjectivity=0.5268879268879268)
# 549
# Sentiment(polarity=0.15227272727272725, subjectivity=0.5659090909090909)
# 550
# Sentiment(polarity=0.297503959455179, subjectivity=0.528718192376729)
# 551
# Sentiment(polarity=0.2585971320346321, subjectivity=0.43501251352813847)
# 552
# Sentiment(polarity=0.18916475681181566, subjectivity=0.4184039000215471)
# 553
# Sentiment(polarity=0.17784090909090913, subjectivity=0.4406163281163279)
# 554
# Sentiment(polarity=0.3194444444444444, subjectivity=0.522718253968254)
# 555
# Sentiment(polarity=0.15576816800221058, subjectivity=0.46279358938933407)
# 556
# Sentiment(polarity=0.13769550342130987, subjectivity=0.4266373411534702)
# 557
# Sentiment(polarity=0.25990909090909087, subjectivity=0.46303030303030307)
# 558
# Sentiment(polarity=0.20714285714285716, subjectivity=0.3908482142857143)
# 559
# Sentiment(polarity=0.12380952380952377, subjectivity=0.3462202380952381)
# 560
# Sentiment(polarity=0.06060606060606062, subjectivity=0.31382575757575754)
# 561
# Sentiment(polarity=0.13651190476190475, subjectivity=0.3874336734693879)
# 562
# Sentiment(polarity=0.13356643356643355, subjectivity=0.3904137529137529)
# 563
# Sentiment(polarity=0.15613831523667593, subjectivity=0.42253915483423676)
# 564
# Sentiment(polarity=0.10121366728509586, subjectivity=0.4529684601113172)
# 565
# Sentiment(polarity=0.21597796143250692, subjectivity=0.5080578512396693)
# 566
# Sentiment(polarity=0.09051837992515961, subjectivity=0.45320089515004763)
# 567
# Sentiment(polarity=0.20113636363636367, subjectivity=0.4337878787878788)
# 568
# Sentiment(polarity=0.19239618406285072, subjectivity=0.4909090909090909)
# 569
# Sentiment(polarity=0.15000000000000002, subjectivity=0.475)
# 570
# Sentiment(polarity=0.0, subjectivity=0.3)
# 571
# Sentiment(polarity=0.2528535353535354, subjectivity=0.568181818181818)
# 572
# Sentiment(polarity=0.20683982683982682, subjectivity=0.37311688311688307)
# 573
# Sentiment(polarity=0.3056586270871986, subjectivity=0.43836322407750977)
# 574
# Sentiment(polarity=0.15452651515151516, subjectivity=0.45376893939393953)
# 575
# Sentiment(polarity=0.12424242424242424, subjectivity=0.37445887445887444)
# 576
# Sentiment(polarity=0.17118176538908245, subjectivity=0.368684668989547)
# 577
# Sentiment(polarity=0.2701569264069264, subjectivity=0.4485119047619048)
# 578
# Sentiment(polarity=0.15998556998556998, subjectivity=0.4154653679653679)
# 579
# Sentiment(polarity=0.16363636363636364, subjectivity=0.571969696969697)
# 580
# Sentiment(polarity=0.1625471861471862, subjectivity=0.4642731601731601)
# 581
# Sentiment(polarity=0.19313725490196076, subjectivity=0.42303921568627445)
# 582
# Sentiment(polarity=0.1344055944055944, subjectivity=0.3927301864801866)
# 583
# Sentiment(polarity=0.090255772005772, subjectivity=0.49761580086580093)
# 584
# Sentiment(polarity=0.11999999999999997, subjectivity=0.58)
# 585
# Sentiment(polarity=0.14113237639553433, subjectivity=0.539988038277512)
# 586
# Sentiment(polarity=0.192946127946128, subjectivity=0.43414853664853653)
# 587
# Sentiment(polarity=0.19656084656084652, subjectivity=0.4590388007054674)
# 588
# Sentiment(polarity=0.14666666666666667, subjectivity=0.3466666666666667)
# 589
# Sentiment(polarity=0.1102202581369248, subjectivity=0.46173140131473467)
# 590
# Sentiment(polarity=0.11365587695133152, subjectivity=0.4881921487603307)
# 591
# Sentiment(polarity=0.21709770114942528, subjectivity=0.5923850574712645)
# 592
# Sentiment(polarity=0.143013468013468, subjectivity=0.4714646464646465)
# 593
# Sentiment(polarity=0.19768885281385282, subjectivity=0.4555838744588743)
# 594
# Sentiment(polarity=0.07967253176930597, subjectivity=0.3774389051808408)
# 595
# Sentiment(polarity=0.21597796143250692, subjectivity=0.5080578512396693)
# 596
# Sentiment(polarity=0.16238738738738737, subjectivity=0.5202702702702703)
# 597
# Sentiment(polarity=0.1355884425651868, subjectivity=0.4602713178294574)
# 598
# Sentiment(polarity=0.2940268065268065, subjectivity=0.5655136530136531)
# 599
# Sentiment(polarity=0.2668371212121212, subjectivity=0.5092045454545455)
# 600
# Sentiment(polarity=0.23687688574052215, subjectivity=0.5324978682933229)
# 601
# Sentiment(polarity=0.0, subjectivity=0.0)
# 602
# Sentiment(polarity=0.16325757575757574, subjectivity=0.5469444444444443)
# 603
# Sentiment(polarity=0.14691263282172373, subjectivity=0.4307802046438409)
# 604
# Sentiment(polarity=0.06060606060606062, subjectivity=0.31382575757575754)
# 605
# Sentiment(polarity=0.27828798185941045, subjectivity=0.49138321995464845)
# 606
# Sentiment(polarity=0.05133200133200133, subjectivity=0.467932067932068)
# 607
# Sentiment(polarity=0.0987012987012987, subjectivity=0.35321067821067814)
# 608
# Sentiment(polarity=0.1954937404937406, subjectivity=0.44991692991692994)
# 609
# Sentiment(polarity=0.15684523809523807, subjectivity=0.4523809523809523)
# 610
# Sentiment(polarity=0.16325757575757574, subjectivity=0.5469444444444443)
# 611
# Sentiment(polarity=0.21597796143250692, subjectivity=0.5080578512396693)
# 612
# Sentiment(polarity=0.10230654761904762, subjectivity=0.3436755952380952)
# 613
# Sentiment(polarity=0.1894207497048406, subjectivity=0.47424881936245583)
# 614
# Sentiment(polarity=0.11926129426129428, subjectivity=0.4897083685545225)
# 615
# Sentiment(polarity=0.20119047619047625, subjectivity=0.3829931972789116)
# 616
# Sentiment(polarity=0.1201697530864198, subjectivity=0.49896604938271605)
# 617
# Sentiment(polarity=0.2585971320346321, subjectivity=0.43501251352813847)
# 618
# Sentiment(polarity=0.24166666666666667, subjectivity=0.43333333333333335)
# 619
# Sentiment(polarity=0.21700336700336698, subjectivity=0.5412457912457912)
# 620
# Sentiment(polarity=0.25043859649122807, subjectivity=0.5890350877192984)
# 621
# Sentiment(polarity=0.26176767676767676, subjectivity=0.5278030303030302)
# 622
# Sentiment(polarity=0.232961972667855, subjectivity=0.3919149477973008)
# 623
# Sentiment(polarity=0.0718944099378882, subjectivity=0.3562111801242236)

# %%
import nltk
from nltk.util import ngrams

from collections import Counter
from operator import itemgetter

from nltk.corpus import stopwords

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.decomposition import NMF

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
# testing with job posts as docs
documents = df_all.job_posting

no_features = 500

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.6, min_df=2, max_features=no_features, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# %%
no_topics = 10

# Run NMF
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)


no_top_words = 12
display_topics(nmf, tfidf_feature_names, no_top_words)
# Out:
# Topic 0:
# machine models techniques statistical algorithms scientist predictive modeling statistics mining using problems
# Topic 1:
# management project support information development technical ability design solutions systems provide including
# Topic 2:
# company world people help digital platform build marketing technology working building engineering
# Topic 3:
# analytics advanced clients client predictive modeling analytical value leadership marketing strategic global
# Topic 4:
# research computational center scientific community software intelligence college scientists ph applications field
# Topic 5:
# risk financial investment firm management quantitative finance state companies models including modeling
# Topic 6:
# health clinical care medical healthcare scientific plan quality appropriate products outcomes support
# Topic 7:
# product products development user metrics quantitative drive digital define manager teams customer
# Topic 8:
# customer sets large marketing like functions analytical analyze database essential perform managing
# Topic 9:
# capgemini client group practice expression global needs collaborative resources delivery www way

# %%
def display_topics(H, W, feature_names, documents, no_top_words, no_top_documents):
    for topic_idx, topic in enumerate(H):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        
        top_doc_indices = np.argsort( W[:,topic_idx] )[::-1][0:no_top_documents]
        for doc_index in top_doc_indices:
            print(doc_index)

documents = df_all.job_posting

no_features = 500

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.6, min_df=2, max_features=no_features, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

no_topics = 10

# Run NMF
nmf_model = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)
nmf_W = nmf_model.transform(tfidf)
nmf_H = nmf_model.components_


no_top_words = 5
no_top_documents = 5
display_topics(nmf_H, nmf_W, tfidf_feature_names, documents, no_top_words, no_top_documents)
# Out:
# Topic 0:
# machine models techniques statistical algorithms
# 294
# 298
# 182
# 251
# 49
# Topic 1:
# management project support information development
# 248
# 348
# 414
# 233
# 118
# Topic 2:
# company world people help digital
# 339
# 198
# 13
# 165
# 365
# Topic 3:
# analytics advanced clients client predictive
# 42
# 32
# 156
# 39
# 387
# Topic 4:
# research computational center scientific community
# 297
# 302
# 46
# 340
# 29
# Topic 5:
# risk financial investment firm management
# 197
# 243
# 237
# 304
# 256
# Topic 6:
# health clinical care medical healthcare
# 215
# 28
# 371
# 102
# 221
# Topic 7:
# product products development user metrics
# 146
# 81
# 150
# 151
# 148
# Topic 8:
# customer sets large marketing like
# 98
# 180
# 137
# 423
# 95
# Topic 9:
# capgemini client group practice expression
# 31
# 383
# 8
# 119
# 396

# %%
df_all.loc[209:242]
# Out:
#                                          company_descr  \
# 209  Crowe Horwath LLP (www.crowehorwath.com) is on...
# 210
# 211  PARA HealthCare Financial Services was founded...
# 212
# 213
# 214
# 215  Sanofi is dedicated to supporting people throu...
# 216
# 217
# 218
# 219  Leidos is a global science and technology solu...
# 220
# 221  Sanofi is dedicated to supporting people throu...
# 222  Red Ventures is a technology company that buil...
# 223
# 224  Marsh is a global leader in insurance broking ...
# 225
# 226
# 227  We’re a diverse collection of thinkers and doe...
# 228  Elsevier is a global information analytics com...
# 229  Hi, we're New York Life, America's largest mut...
# 230  Ekimetrics is a global consulting firm, pionne...
# 231  Connections of New York, Inc. is an establishe...
# 232  Founded in 2004, Facebook’s mission is to give...
# 233  The United Nations Development Programme works...
# 234  If you'd just like to tumble along and see wha...
# 235
# 236  All your music is here.\n\nSpotify gives you m...
# 237  At JPMorgan Chase, the work we do matters. All...
# 238
# 239
# 240
# 241
# 242  Ralph Lauren, whose name is synonymous with Am...
#
#                           company_name        date_posted  \
# 209                      Crowe Horwath         3 days ago
# 210                         Comcentric         3 days ago
# 211     PARA HealthCare Analytics, Inc         3 days ago
# 212                               Arch         2 days ago
# 213        EZEN Computer Services Inc.         3 days ago
# 214                         Pleio, Inc         2 days ago
# 215                          Sanofi US         3 days ago
# 216               Omnicom Health Group         4 days ago
# 217                             Turner         4 days ago
# 218  Altamira Technologies Corporation         3 days ago
# 219                             Leidos         3 days ago
# 220                          Dataspace         3 days ago
# 221                          Sanofi US         3 days ago
# 222                       Red Ventures         2 days ago
# 223                        Lazard Ltd.         2 days ago
# 224                              Marsh         5 days ago
# 225             University of Michigan         3 days ago
# 226            Magpie Health Analytics         3 days ago
# 227                              Apple  Posted 2 days ago
# 228                           Elsevier  Posted 3 days ago
# 229    New York Life Insurance Company  Posted 3 days ago
# 230                         Ekimetrics  Posted 3 days ago
# 231            Connections of New York  Posted 2 days ago
# 232                           Facebook  Posted 2 days ago
# 233                               UNDP  Posted 3 days ago
# 234                             Tumblr         2 days ago
# 235             Sunsoft Services, Inc.         2 days ago
# 236                            Spotify         2 days ago
# 237                    JP Morgan Chase         5 days ago
# 238                            Kasisto         3 days ago
# 239           Techwave Consulting Inc.         4 days ago
# 240                             Crushh         5 days ago
# 241                Nexcelom Bioscience         5 days ago
# 242                       Ralph Lauren         3 days ago
#
#                                          email_content  \
# 209  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 210  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 211  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 212  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 213  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 214  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 215  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 216  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 217  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 218  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 219  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 220  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 221  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 222  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 223  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 224  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 225  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 226  Indeed Job Alert data science jobs  Jobs 1-30 ...
# 227  LinkedIn | 929 new jobs matching your search f...
# 228  LinkedIn | 929 new jobs matching your search f...
# 229  LinkedIn | 929 new jobs matching your search f...
# 230  LinkedIn | 929 new jobs matching your search f...
# 231  LinkedIn | 929 new jobs matching your search f...
# 232  LinkedIn | 929 new jobs matching your search f...
# 233  LinkedIn | 929 new jobs matching your search f...
# 234  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
# 235  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
# 236  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
# 237  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
# 238  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
# 239  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
# 240  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
# 241  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
# 242  Recommended Jobs for You  Jobs 1 to 40 of 51 r...
#
#                                 email_date           email_from  \
# 209  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 210  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 211  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 212  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 213  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 214  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 215  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 216  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 217  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 218  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 219  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 220  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 221  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 222  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 223  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 224  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 225  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 226  Fri, 23 Feb 2018 17:42:17 -0600 (CST)               Indeed
# 227  Sat, 24 Feb 2018 00:53:25 +0000 (UTC)  LinkedIn Job Alerts
# 228  Sat, 24 Feb 2018 00:53:25 +0000 (UTC)  LinkedIn Job Alerts
# 229  Sat, 24 Feb 2018 00:53:25 +0000 (UTC)  LinkedIn Job Alerts
# 230  Sat, 24 Feb 2018 00:53:25 +0000 (UTC)  LinkedIn Job Alerts
# 231  Sat, 24 Feb 2018 00:53:25 +0000 (UTC)  LinkedIn Job Alerts
# 232  Sat, 24 Feb 2018 00:53:25 +0000 (UTC)  LinkedIn Job Alerts
# 233  Sat, 24 Feb 2018 00:53:25 +0000 (UTC)  LinkedIn Job Alerts
# 234  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
# 235  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
# 236  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
# 237  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
# 238  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
# 239  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
# 240  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
# 241  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
# 242  Sat, 24 Feb 2018 13:23:43 -0600 (CST)     Indeed Job Alert
#
#                                          email_subject  \
# 209                          30+ new data science jobs
# 210                          30+ new data science jobs
# 211                          30+ new data science jobs
# 212                          30+ new data science jobs
# 213                          30+ new data science jobs
# 214                          30+ new data science jobs
# 215                          30+ new data science jobs
# 216                          30+ new data science jobs
# 217                          30+ new data science jobs
# 218                          30+ new data science jobs
# 219                          30+ new data science jobs
# 220                          30+ new data science jobs
# 221                          30+ new data science jobs
# 222                          30+ new data science jobs
# 223                          30+ new data science jobs
# 224                          30+ new data science jobs
# 225                          30+ new data science jobs
# 226                          30+ new data science jobs
# 227             Arina: 929 new jobs for 'data science'
# 228             Arina: 929 new jobs for 'data science'
# 229             Arina: 929 new jobs for 'data science'
# 230             Arina: 929 new jobs for 'data science'
# 231             Arina: 929 new jobs for 'data science'
# 232             Arina: 929 new jobs for 'data science'
# 233             Arina: 929 new jobs for 'data science'
# 234  You have new recommended jobs: Data Scientist ...
# 235  You have new recommended jobs: Data Scientist ...
# 236  You have new recommended jobs: Data Scientist ...
# 237  You have new recommended jobs: Data Scientist ...
# 238  You have new recommended jobs: Data Scientist ...
# 239  You have new recommended jobs: Data Scientist ...
# 240  You have new recommended jobs: Data Scientist ...
# 241  You have new recommended jobs: Data Scientist ...
# 242  You have new recommended jobs: Data Scientist ...
#
#                                          job_post_link  \
# 209  https://www.indeed.com/viewjob?jk=c8b74be9782f...
# 210  https://www.indeed.com/viewjob?jk=f07408e46d83...
# 211  https://www.indeed.com/viewjob?jk=b942842395c8...
# 212  https://www.indeed.com/viewjob?jk=14d660a43a6f...
# 213  https://www.indeed.com/viewjob?jk=7c739cc0ff86...
# 214  https://www.indeed.com/viewjob?jk=dce6fe9d9262...
# 215  https://www.indeed.com/viewjob?jk=b3622e5372e1...
# 216  https://www.indeed.com/viewjob?jk=85a979680b1c...
# 217  https://www.indeed.com/viewjob?jk=7c5e15716b7b...
# 218  https://www.indeed.com/viewjob?jk=7d5a580c49d6...
# 219  https://www.indeed.com/viewjob?jk=fb562d69cf57...
# 220  https://www.indeed.com/viewjob?jk=e0f44a614569...
# 221  https://www.indeed.com/viewjob?jk=26e323c11f8a...
# 222  https://www.indeed.com/viewjob?jk=4831241bd502...
# 223  https://www.indeed.com/viewjob?jk=86e08c21ad96...
# 224  https://www.indeed.com/viewjob?jk=0d5365667027...
# 225  https://www.indeed.com/viewjob?jk=9ed9da2ed22a...
# 226  https://www.indeed.com/viewjob?jk=f1f63c9d397f...
# 227  https://www.linkedin.com/comm/jobs/view/569526...
# 228  https://www.linkedin.com/comm/jobs/view/607648...
# 229  https://www.linkedin.com/comm/jobs/view/607611...
# 230  https://www.linkedin.com/comm/jobs/view/607554...
# 231  https://www.linkedin.com/comm/jobs/view/607749...
# 232  https://www.linkedin.com/comm/jobs/view/569530...
# 233  https://www.linkedin.com/comm/jobs/view/607282...
# 234  https://www.indeed.com/viewjob?jk=69620818e300...
# 235  https://www.indeed.com/viewjob?jk=dcdda1469533...
# 236  https://www.indeed.com/viewjob?jk=2c80ebd66309...
# 237  https://www.indeed.com/viewjob?jk=40ccc163e010...
# 238  https://www.indeed.com/viewjob?jk=c2a98c21db86...
# 239  https://www.indeed.com/viewjob?jk=cad8c3214165...
# 240  https://www.indeed.com/viewjob?jk=6d58990dbb0a...
# 241  https://www.indeed.com/viewjob?jk=c25c9cc40a25...
# 242  https://www.indeed.com/viewjob?jk=3b82833a3ecc...
#
#                                            job_posting  \
# 209   \nleverage large sets of structured and unstr...
# 210  we are seeking a big data engineer for a 12 mo...
# 211  para healthcare analytics, inc. was founded in...
# 212  overview\nthe company\narch capital group ltd....
# 213  title: data scientist\n: richardson, tx\ndurat...
# 214  data analyst (remote)\n description\nabout ple...
# 215  the medical science liaison (msl) will be resp...
# 216  title: director data and analytics\ncompany / ...
# 217  : the senior vice president, data, analytics, ...
# 218  altamira is a top open source technology compa...
# 219  description:\nat leidos we combine our deep cu...
# 220  are you trying to grow your career from databa...
# 221   \nthe field scientific director (fsd) in fabr...
# 222  data science at red ventures:\nred ventures is...
# 223  lazard\nsummer data science intern\n\n descrip...
# 224   :\n\nas a data analyst in the centralized ope...
# 225  how to apply a cover letter is  for considerat...
# 226   purpose (your challenge):\nare you ready to h...
# 227  the sds team provides analytic support across ...
# 228  vp data science                               ...
# 229  new york life insurance company (“new york lif...
# 230  ekimetrics\n\nto sustain our quick growth, we ...
# 231  vp data science senior java developer\n  descr...
# 232  over 800 million people use instagram, which m...
# 233  background\n\nundp’s strategic plan (2018-2021...
# 234  tumblr is looking for data scientists to use t...
# 235  role: full time\nvisa: usc/gc\nmoi: telephonic...
# 236  we are looking for a data scientist to join ou...
# 237  jpmorgan chase & co. (nyse: jpm) is a leading ...
# 238  kasisto, a fintech startup, is on a mission to...
# 239  data scientist's (ds’s) create answers to clie...
# 240   \ncrushh is a unique mobile app (www.crushhap...
# 241  field application scientist : metro nyc or phi...
# 242  ralph lauren corporation is a global leader in...
#
#                                              job_title  \
# 209  Data Scientist/Statistics - Applied Technology...
# 210                        Remote Big Data opportunity
# 211                Healthcare Data Analyst (US-Remote)
# 212       Data Scientist, Strategic Analytics Services
# 213                                     Data Scientist
# 214                              Data Analyst (Remote)
# 215                            Medical Science Liaison
# 216                           Director, Data Analytics
# 217                    SVP, Data Analytics/Decision Sc
# 218                                     Data Scientist
# 219                                Data Science Intern
# 220                               Data Science Analyst
# 221                      Field Science Director, Fabry
# 222                              Senior Data Scientist
# 223                                Data Science Intern
# 224                           Data Analytics Developer
# 225                                     Data Scientist
# 226                              Health Data Scientist
# 227                               Data Science Analyst
# 228                                    Data Science-VP
# 229            Senior Solutions Associate Data Science
# 230  Senior Consultant, Marketing Analytics and Dat...
# 231               Senior Java Developer (Data Science)
# 232    Data Science Manager, Analytics (Instagram NYC)
# 233  Data Science and Management Consultant - New York
# 234                                     Data Scientist
# 235                                     Data Scientist
# 236                 Data Scientist (Royalty Analytics)
# 237  CCB - Risk-Fraud Data Scientist/Modeler-ML-Ass...
# 238                                     Data Scientist
# 239                   Data Scientist - Jr. / Mid Level
# 240  Machine & Deep Learning Data Scientist Internship
# 241                        Field Application Scientist
# 242        ANALYST, PRODUCTION OPERATIONS (TECHNOLOGY)
#
#                        location                 job_role job_level country  \
# 209      Indianapolis, IN 46240           data scientist               USA
# 210               United States       data science other               USA
# 211                      Remote             data analyst
# 212             Jersey City, NJ           data scientist               USA
# 213              Richardson, TX           data scientist               USA
# 214                  Newark, NJ             data analyst               USA
# 215               United States                                        USA
# 216                New York, NY    data science director    senior     USA
# 217           Atlanta, GA 30319    data science director    senior     USA
# 218                   Tampa, FL           data scientist               USA
# 219         Arlington, VA 22202       data science other    intern     USA
# 220         Ann Arbor, MI 48103             data analyst               USA
# 221               United States    data science director    senior     USA
# 222               Charlotte, NC           data scientist    senior     USA
# 223                New York, NY       data science other    intern     USA
# 224               United States   data science developer               USA
# 225               Ann Arbor, MI           data scientist               USA
# 226              Clearwater, FL           data scientist               USA
# 227                Shanghai, CN             data analyst               USA
# 228          New York, New York    data science director    senior     USA
# 229       New York City, NY, US       data science other    junior     USA
# 230          New York, New York  data science consultant    senior     USA
# 231  Greater New York City Area   data science developer    senior     USA
# 232       New York City, NY, US     data science manager    senior     USA
# 233       New York City, NY, US  data science consultant               USA
# 234                New York, NY           data scientist               USA
# 235                New York, NY           data scientist               USA
# 236          New York, NY 10011           data scientist               USA
# 237          New York, NY 10001           data scientist    junior     USA
# 238                New York, NY           data scientist               USA
# 239          New York, NY 10022           data scientist    junior     USA
# 240                New York, NY           data scientist    intern     USA
# 241                New York, NY           data scientist               USA
# 242                New York, NY             data analyst               USA
#
#          state          city job_post_date  equal_opportunity_clause
# 209         IN  Indianapolis    2018-02-23                         0
# 210                             2018-02-23                         0
# 211                             2018-02-23                         0
# 212         NJ   Jersey City    2018-02-24                         0
# 213         TX    Richardson    2018-02-23                         0
# 214         NJ        Newark    2018-02-24                         0
# 215                             2018-02-23                         0
# 216         NY      New York    2018-02-22                         0
# 217         GA       Atlanta    2018-02-22                         1
# 218         FL         Tampa    2018-02-23                         1
# 219         VA     Arlington    2018-02-23                         1
# 220         MI     Ann Arbor    2018-02-23                         0
# 221                             2018-02-23                         0
# 222         NC     Charlotte    2018-02-24                         0
# 223         NY      New York    2018-02-24                         0
# 224                             2018-02-21                         1
# 225         MI     Ann Arbor    2018-02-23                         0
# 226         FL    Clearwater    2018-02-23                         0
# 227         CN      Shanghai    2018-02-24                         0
# 228   New York      New York    2018-02-23                         0
# 229         NY      New York    2018-02-23                         0
# 230   New York      New York    2018-02-23                         0
# 231         NY      New York    2018-02-24                         0
# 232         NY      New York    2018-02-24                         1
# 233         NY      New York    2018-02-23                         1
# 234         NY      New York    2018-02-24                         1
# 235         NY      New York    2018-02-24                         0
# 236         NY      New York    2018-02-24                         0
# 237         NY      New York    2018-02-21                         0
# 238         NY      New York    2018-02-23                         0
# 239         NY      New York    2018-02-22                         0
# 240         NY      New York    2018-02-21                         0
# 241         NY      New York    2018-02-21                         0
# 242         NY      New York    2018-02-23                         1

# %%
df_all.loc[428].job_post_link
# Out:
# 'https://www.indeed.com/viewjob?jk=c54019e3d2f3060e&from=rje&rgtk=1c773s9vb05l66lg'

# %%
# calculating cosine similarities
from sklearn.preprocessing import normalize

# %%
norm_features = normalize(nmf_W)
norm_features
# Out:
# array([[ 0.7717836 ,  0.        ,  0.61287696, ...,  0.1695049 ,
#          0.        ,  0.        ],
#        [ 0.72612043,  0.        ,  0.65179208, ...,  0.21889768,
#          0.        ,  0.        ],
#        [ 0.07541182,  0.        ,  0.66253316, ...,  0.23151346,
#          0.        ,  0.        ],
#        ...,
#        [ 0.56148583,  0.        ,  0.82475522, ...,  0.04857007,
#          0.        ,  0.        ],
#        [ 0.        ,  0.21675788,  0.56410612, ...,  0.        ,
#          0.3110409 ,  0.        ],
#        [ 0.35028428,  0.92508306,  0.        , ...,  0.        ,
#          0.14613429,  0.        ]])

# %%
target_doc1 = norm_features[0,:]
target_doc1
# Out:
# array([ 0.7717836 ,  0.        ,  0.61287696,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.1695049 ,  0.        ,  0.        ])

# %%
similarities = norm_features.dot(target_doc1)
similarities
# Out:
# array([  1.00000000e+00,   9.96980421e-01,   5.03495577e-01,
#          7.57780400e-01,   7.40475237e-01,   5.16117083e-01,
#          8.44297084e-01,   7.30987933e-01,   5.98134684e-02,
#          8.95349112e-01,   9.56641731e-01,   6.87744485e-01,
#          1.97295505e-01,   5.92948108e-01,   3.38271665e-01,
#          7.28506626e-02,   5.78675675e-01,   1.47748101e-01,
#          3.75548830e-01,   8.07581860e-01,   0.00000000e+00,
#          4.52136498e-01,   4.42090660e-01,   5.90584170e-01,
#          2.64192133e-01,   5.42752189e-01,   4.31632748e-01,
#          7.50515989e-01,   6.22231402e-02,   1.61772443e-01,
#          7.90978713e-01,   1.04684035e-01,   1.07118944e-01,
#          7.89423413e-01,   6.58304329e-01,   7.81448168e-02,
#          9.29794671e-01,   4.80271179e-01,   6.61274601e-01,
#          2.83938321e-01,   5.56300289e-01,   3.61309220e-01,
#          9.71077779e-02,   7.14344429e-01,   8.75414528e-01,
#          0.00000000e+00,   9.73279173e-02,   7.95990012e-01,
#          7.09333178e-01,   7.80473216e-01,   9.01862442e-01,
#          5.20196933e-01,   1.60071160e-01,   7.00105609e-01,
#          5.34564994e-01,   5.62581559e-02,   7.13146535e-01,
#          5.17034466e-01,   6.22157581e-01,   6.90374088e-01,
#          3.37917545e-01,   7.87453207e-01,   2.23631426e-01,
#          8.07440586e-01,   1.66636101e-01,   4.84042982e-01,
#          9.65641598e-01,   7.71058373e-01,   2.77084777e-01,
#          7.24248347e-01,   0.00000000e+00,   9.32120899e-01,
#          4.38053773e-01,   2.29799821e-01,   6.12217655e-01,
#          3.19710328e-01,   7.99997394e-01,   4.69766295e-01,
#          6.63242412e-01,   5.08254513e-02,   7.71807462e-02,
#          4.72605406e-01,   5.68361205e-01,   5.79879811e-01,
#          9.92971567e-01,   6.42733582e-01,   9.53545965e-01,
#          5.60503271e-01,   6.38604653e-01,   2.03707268e-01,
#          6.58867041e-01,   4.77276788e-01,   8.98656916e-01,
#          5.53165044e-01,   4.25037840e-01,   1.64179492e-01,
#          7.36589987e-01,   8.29341958e-01,   0.00000000e+00,
#          6.37020364e-01,   8.37206061e-01,   7.59371995e-01,
#          8.45296934e-02,   8.90712924e-01,   5.77784429e-01,
#          4.93510336e-01,   2.41759503e-01,   4.61513576e-01,
#          6.57324544e-01,   9.51112180e-01,   7.54523757e-01,
#          5.67632230e-01,   6.03687623e-01,   6.72383541e-01,
#          0.00000000e+00,   7.28685564e-01,   7.12114635e-01,
#          6.09207883e-01,   0.00000000e+00,   1.34168862e-01,
#          9.85158251e-01,   6.65521098e-02,   7.15242668e-01,
#          5.59724850e-01,   7.28745271e-01,   8.15099004e-01,
#          5.04961056e-01,   7.14077713e-01,   4.82274379e-01,
#          6.60675488e-01,   4.75139176e-01,   5.77415024e-01,
#          6.57641093e-01,   7.59256779e-04,   6.49312810e-01,
#          6.89064189e-01,   3.14990235e-01,   0.00000000e+00,
#          8.60183264e-01,   3.56537762e-01,   5.35279868e-01,
#          5.01342989e-01,   6.01530113e-01,   6.06604714e-01,
#          1.16285566e-01,   1.97920709e-02,   2.06763424e-01,
#          1.71286884e-01,   2.35118045e-01,   6.10019022e-01,
#          2.90520722e-01,   2.33204891e-01,   3.83258436e-01,
#          8.87383480e-01,   3.20815554e-01,   1.75889995e-02,
#          1.77650501e-01,   7.68867490e-01,   5.08707915e-01,
#          5.71515631e-01,   5.43386287e-01,   7.73722294e-01,
#          7.88784313e-01,   7.68233067e-01,   7.71783599e-01,
#          6.03434137e-01,   8.88462971e-01,   9.42247099e-01,
#          7.90145064e-01,   8.04904989e-01,   7.03635854e-02,
#          5.21052287e-01,   9.72472468e-01,   8.84254977e-01,
#          5.99064555e-01,   4.12162450e-01,   4.42945587e-01,
#          2.50355753e-01,   2.51034609e-01,   6.00022776e-01,
#          0.00000000e+00,   2.33693279e-01,   8.24829691e-01,
#          4.81032938e-02,   5.54429532e-01,   6.07517555e-01,
#          4.58499219e-01,   3.65172322e-01,   5.79513526e-01,
#          5.91791027e-01,   7.36286503e-01,   5.88478412e-01,
#          9.27526859e-01,   6.86053933e-01,   3.03495009e-01,
#          3.34539574e-01,   6.28018869e-01,   5.00402965e-02,
#          6.73737344e-01,   2.83964307e-01,   5.00483823e-01,
#          1.30370411e-01,   6.24049196e-02,   2.92014603e-01,
#          9.25972231e-02,   6.16360380e-01,   1.63971454e-01,
#          7.34284836e-01,   8.20769912e-01,   7.19225451e-01,
#          7.27136558e-01,   0.00000000e+00,   6.80723361e-01,
#          6.84955035e-01,   2.69793578e-01,   1.48277080e-02,
#          1.11838387e-01,   3.50026660e-01,   7.00398494e-01,
#          6.15972999e-01,   6.10043091e-01,   4.38768548e-02,
#          6.34722012e-01,   4.80250783e-01,   2.65370667e-01,
#          2.46306027e-01,   3.09351630e-01,   6.81732160e-01,
#          4.18117882e-01,   3.50952568e-01,   3.19248449e-01,
#          3.07947570e-01,   6.44726474e-01,   4.73452998e-02,
#          7.60528611e-01,   7.47558223e-01,   8.82229262e-01,
#          2.64251213e-01,   8.05211245e-01,   2.38419989e-01,
#          7.47039797e-01,   2.86181928e-01,   1.24340337e-01,
#          0.00000000e+00,   1.73911376e-01,   4.73475520e-01,
#          6.59647924e-01,   6.25943178e-01,   0.00000000e+00,
#          9.91880109e-02,   6.95489669e-01,   7.70675591e-01,
#          3.09614329e-01,   8.23277590e-01,   3.56764427e-01,
#          8.81327320e-01,   2.13637257e-01,   4.77812091e-01,
#          3.50593022e-01,   8.72233343e-01,   2.52290465e-01,
#          5.36628037e-01,   0.00000000e+00,   5.80491635e-01,
#          0.00000000e+00,   2.37267094e-01,   4.22681819e-01,
#          9.52299576e-01,   3.30508435e-01,   7.07314827e-01,
#          4.26140037e-01,   8.71527186e-01,   6.17423855e-01,
#          7.37020575e-01,   2.41021106e-01,   6.71679939e-01,
#          9.46265581e-01,   9.51952783e-01,   2.75679296e-01,
#          4.77406277e-01,   5.06785851e-01,   8.21424092e-01,
#          9.56738704e-01,   5.94265059e-01,   4.79737246e-01,
#          4.80293715e-01,   7.16227579e-01,   2.63843517e-01,
#          9.21274821e-01,   7.66661359e-01,   7.90626480e-01,
#          6.17042042e-02,   9.38373657e-01,   5.87892659e-01,
#          7.37926189e-01,   4.95578857e-01,   5.44540755e-01,
#          2.66610274e-02,   7.42614526e-01,   9.43424963e-01,
#          9.59986216e-01,   8.57082793e-01,   0.00000000e+00,
#          8.57014403e-01,   2.75834477e-01,   7.38785908e-01,
#          7.04590294e-01,   6.30209233e-01,   2.65355990e-01,
#          7.24995658e-01,   7.53019660e-01,   8.58217169e-01,
#          7.12591845e-01,   2.02108051e-01,   7.39795446e-03,
#          7.27994844e-01,   8.72337450e-01,   0.00000000e+00,
#          6.30028915e-01,   7.09940414e-01,   4.26140037e-01,
#          6.34489333e-01,   9.06398608e-01,   7.78681861e-01,
#          1.92431038e-01,   6.69571650e-01,   5.17034466e-01,
#          1.40974971e-01,   5.46826857e-01,   3.42965595e-01,
#          6.68366389e-01,   3.34531834e-02,   6.04192977e-01,
#          2.70127866e-01,   8.48960084e-01,   1.08529321e-01,
#          9.12038712e-01,   2.21781285e-01,   3.18177854e-01,
#          6.73737344e-01,   2.41567324e-01,   7.20530087e-01,
#          2.07899831e-01,   7.71001339e-01,   4.62630776e-01,
#          7.74827565e-02,   3.84491649e-02,   3.39217633e-01,
#          6.99444575e-02,   8.01214914e-01,   5.07489219e-01,
#          7.15090103e-01,   5.13343332e-01,   9.02982502e-01,
#          6.84322996e-01,   8.39483995e-01,   8.34955166e-01,
#          5.96396450e-01,   7.10140365e-01,   8.95066753e-01,
#          9.55240008e-01,   9.69186459e-01,   0.00000000e+00,
#          1.55023581e-01,   4.66217630e-01,   6.45760571e-01,
#          3.81612338e-01,   7.29382595e-01,   3.49159079e-01,
#          4.98254682e-01,   8.90633535e-01,   8.04549128e-02,
#          1.90095848e-01,   4.71740319e-01,   4.63697643e-01,
#          0.00000000e+00,   1.11037626e-01,   3.23332491e-01,
#          3.56295982e-01,   7.83481287e-01,   9.40715250e-01,
#          6.44488758e-02,   7.02705207e-01,   1.23548865e-01,
#          7.44862710e-01,   2.46717128e-01,   9.11024678e-01,
#          2.91418088e-01,   8.41209042e-01,   7.33960762e-01,
#          3.79036758e-01,   7.71783599e-01,   3.81148300e-02,
#          8.65901065e-01,   7.77996752e-01,   5.33323578e-01,
#          6.20930449e-01,   1.20956326e-01,   6.06806522e-02,
#          7.06841297e-01,   3.14678426e-01,   8.12235560e-01,
#          6.09276816e-01,   5.27342347e-01,   2.61085797e-01,
#          4.88886352e-01,   1.08424699e-03,   9.36984409e-01,
#          6.61538324e-01,   3.77278531e-01,   7.63989365e-01,
#          3.94909692e-01,   5.43535725e-01,   5.46126432e-01,
#          3.28735396e-02,   8.92742636e-01,   6.99446076e-01,
#          7.94378728e-01,   6.44514426e-01,   3.75891574e-01,
#          7.20002362e-01,   5.90858424e-01,   5.27019563e-02,
#          0.00000000e+00,   8.46686217e-01,   9.47051890e-01,
#          3.45727642e-01,   2.70343666e-01])

# %%
job_titles = df_all.job_title

# %%
norm_features_df = pd.DataFrame(norm_features, index=job_titles)
norm_features_df.head()
# Out:
#                                         0      1      2      3      4      5  \
# job_title
# Senior Data Scientist               0.772  0.000  0.613  0.000  0.000  0.000
# Data Scientist                      0.726  0.000  0.652  0.000  0.000  0.000
# Data Scientist                      0.075  0.000  0.663  0.708  0.020  0.000
# Data Scientist / Signal Researcher  0.679  0.000  0.381  0.000  0.340  0.527
# Data Scientist Intern               0.211  0.062  0.942  0.000  0.252  0.000
#
#                                       6      7    8    9
# job_title
# Senior Data Scientist               0.0  0.170  0.0  0.0
# Data Scientist                      0.0  0.219  0.0  0.0
# Data Scientist                      0.0  0.232  0.0  0.0
# Data Scientist / Signal Researcher  0.0  0.000  0.0  0.0
# Data Scientist Intern               0.0  0.000  0.0  0.0

# %%
target_doc1b = norm_features_df.iloc[0]

# %%
similarities = norm_features_df.dot(target_doc1b)
print(similarities.nlargest(10))
# Out:
# job_title
# Senior Data Scientist                           1.000
# Data Scientist                                  0.997
# Data Scientist                                  0.993
# Data Science Intern                             0.985
# Data Scientist - Sr Level - 120k-140k           0.972
# Data Science Intern                             0.969
# Data Scientist                                  0.966
# Data Scientist (PYTHON, HADOOP)                 0.960
# Data Scientist                                  0.957
# Data Scientist - Alexa Language Technologies    0.957
# dtype: float64

# %%
target_doc2b = norm_features_df.iloc[4]

# %%
similarities2 = norm_features_df.dot(target_doc2b)
print(similarities2.nlargest(10))
# Out:
# job_title
# Data Scientist Intern                            1.000
# Data Scientist                                   0.979
# Data Scientist                                   0.979
# Machine Learning Educator / Research Engineer    0.969
# Data Scientist                                   0.965
# Applied Data Scientist                           0.965
# Principal Data Scientist                         0.962
# Data Scientist                                   0.962
# Senior Data Scientist (Life Science Startup)     0.962
# Software Engineer, Machine Learning              0.961
# dtype: float64

# %%
print((similarities - similarities2).nlargest(10))
# Out:
# job_title
# Data Scientist                                                        0.561
# Data Scientist                                                        0.561
# Data Scientist                                                        0.557
# Data Scientist                                                        0.552
# Data Scientist @ Apple                                                0.536
# Data Scientist - Data Modelling (or) Machine learning (US Citizen)    0.535
# Data Scientist                                                        0.534
# Data Scientist - Top Secret (TS) Clearance Required                   0.532
# Data Scientist Intern                                                 0.530
# Data Scientist (ASD)                                                  0.529
# dtype: float64

# %% [markdown]
# ## Topic modeling on subsets

# %%
df_all.job_role.value_counts()
# Out:
# data scientist             326
# data analyst                70
# data science director       54
# data science other          42
# data science manager        41
# data engineer               32
# data science developer      20
#                             18
# data science consultant     14
# data science researcher      4
# data science academia        3
# Name: job_role, dtype: int64

# %%
df_all.job_level.value_counts()
# Out:
#           418
# senior    145
# intern     41
# junior     20
# Name: job_level, dtype: int64

# %%
# testing with job posts as docs
#sliced = df_all[df_all.job_role == 'data analyst'].copy()
sliced = df_all[(df_all.job_level == '') | (df_all.job_level == 'junior')].copy()
documents = sliced.job_posting

no_features = 500

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.6, min_df=2, max_features=no_features, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()


no_topics = 10

# Run NMF
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)


no_top_words = 12
display_topics(nmf, tfidf_feature_names, no_top_words)
# Out:
# Topic 0:
# analytics models new techniques problems ability scientist statistical using develop strong statistics
# Topic 1:
# google hadoop big growing content production build systems scale web plus real
# Topic 2:
# firm advisory group investment private partners candidates services information clients results technology
# Topic 3:
# research software computational clearance center security scientific intelligence engineering federal technology development
# Topic 4:
# ll requires analytics engineering make decision help bring professionals produce right experienced
# Topic 5:
# customer marketing sets functions large like database analytical managing analyze oriented perform
# Topic 6:
# capgemini client group practice management global digital collaborative needs services media solutions
# Topic 7:
# reliability engineering quality automation resources discipline physics providing cross functional focused database
# Topic 8:
# 000 support scientific 10 requires broad language management program presentations subject operations
# Topic 9:
# health medical care clinical healthcare individual plan devices complex digital assist enterprise
